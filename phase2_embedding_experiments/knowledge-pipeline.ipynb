# %% [markdown]
# # Demonstarating the Knowledge Pipeline
#
# DeepDoc --> Partitioner --> Enrichement --> Global Entities --> Chunker --> Embedder in phases

# %% [markdown]
# ✅ Phase 1: DeepDoc – Loader + Preprocessor
# 🎯 Objective:
# Load a document (PDF/Word/Text), extract clean text, and basic metadata (like page numbers, headings, etc.)
#
#                             Tools we are going to use
#
# | Task                | Tool                                      |
# | ------------------- | ----------------------------------------- |
# | PDF Reading         | `pdfplumber` (more accurate) or `PyMuPDF` |
# | DOCX Reading        | `python-docx`                             |
# | Text Cleaning       | `re` (regex), `unicodedata`, etc.         |
# | Metadata Extraction | Basic heuristics                          |

# %%
# Step 0 : Installing required libraries for the Phase1
# !pip install pdfplumber python-docx unstructured
# Out:
# Requirement already satisfied: pdfplumber in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (0.11.7)
# Requirement already satisfied: python-docx in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: unstructured in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (0.18.11)
# Requirement already satisfied: pdfminer.six==20250506 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pdfplumber) (20250506)
# Requirement already satisfied: Pillow>=9.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pdfplumber) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pdfminer.six==20250506->pdfplumber) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pdfminer.six==20250506->pdfplumber) (45.0.5)
# Requirement already satisfied: lxml>=3.1.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from python-docx) (6.0.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from python-docx) (4.14.1)
# Requirement already satisfied: filetype in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: nltk in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (4.13.4)
# Requirement already satisfied: emoji in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (2.14.1)
# Requirement already satisfied: dataclasses-json in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (2.3.1)
# Requirement already satisfied: rapidfuzz in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (3.13.0)
# Requirement already satisfied: backoff in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: unstructured-client in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (0.41.0)
# Requirement already satisfied: wrapt in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (1.17.2)
# Requirement already satisfied: tqdm in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (7.0.0)
# Requirement already satisfied: python-oxmsg in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from beautifulsoup4->unstructured) (2.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from nltk->unstructured) (8.2.1)
# Requirement already satisfied: joblib in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from nltk->unstructured) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: olefile in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests->unstructured) (2025.7.14)
# Requirement already satisfied: aiofiles>=24.1.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic>=2.11.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (2.11.7)
# Requirement already satisfied: pypdf>=4.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (5.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.14 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (1.17.1)
# Requirement already satisfied: h11>=0.16 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.9.0)
# Requirement already satisfied: packaging>=17.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: pycparser in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber) (2.22)
# Requirement already satisfied: sniffio>=1.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)

# %%
# Step 1: Load a PDF File and Extract Text (Using pdfplumber)
import pdfplumber

pdf_path = "sample.pdf"  # Replace with your local file path

text_pages = []
with pdfplumber.open(pdf_path) as pdf:
    for i, page in enumerate(pdf.pages):
        text = page.extract_text()
        if text:
            text_pages.append({
                "page_number": i + 1,
                "text": text.strip()
            })

print(f"Total Pages: {len(text_pages)}")
print(text_pages[0])  # Print first page preview
# Out:
# Total Pages: 98
# {'page_number': 1, 'text': 'CloudContactCenter\nSoftware\nTechnical Requirements\nReference Guide\nAugust 2021\nThis guide contains deployment, configuration, and troubleshooting\ninformation to assist customers and partners with Five9 applications.\nFive9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe\nclaimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange\nwithoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright © 2021Five9,Inc.'}

# %%
# 🧽 Step 2: Basic Preprocessing

import re
import unicodedata

def clean_text(text):
    text = unicodedata.normalize("NFKC", text)  # Normalize unicode
    text = re.sub(r'\s+', ' ', text)  # Remove excess whitespace
    text = re.sub(r'[^\x00-\x7F]+', '', text)  # Remove non-ASCII chars
    return text.strip()

for page in text_pages:
    page["cleaned_text"] = clean_text(page["text"])
    print(page)
# Out:
# {'page_number': 1, 'text': 'CloudContactCenter\nSoftware\nTechnical Requirements\nReference Guide\nAugust 2021\nThis guide contains deployment, configuration, and troubleshooting\ninformation to assist customers and partners with Five9 applications.\nFive9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe\nclaimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange\nwithoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright © 2021Five9,Inc.', 'cleaned_text': 'CloudContactCenter Software Technical Requirements Reference Guide August 2021 This guide contains deployment, configuration, and troubleshooting information to assist customers and partners with Five9 applications. Five9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe claimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange withoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright  2021Five9,Inc.'}
# {'page_number': 2, 'text': 'About Five9\nFive9istheleadingproviderofcloudcontactcentersoftware,bringingthepowerof\nthecloudtothousandsofcustomersandfacilitatingmorethanthreebillioncustomer\ninteractionsannually.Since2001,Five9hasledthecloudrevolutionincontactcenters,\ndeliveringsoftwaretohelporganizationsofeverysizetransitionfrompremise-based\nsoftwaretothecloud.Withitsextensiveexpertise,technology,andecosystemof\npartners,Five9deliverssecure,reliable,scalablecloudcontactcentersoftwaretohelp\nbusinessescreateexceptionalcustomerexperiences,increaseagentproductivityand\ndelivertangibleresults.Formoreinformationvisitwww.five9.com.\nTrademarks\nFive9®\nFive9Logo\nFive9®SoCoCare™\nFive9®Connect™\n2 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'About Five9 Five9istheleadingproviderofcloudcontactcentersoftware,bringingthepowerof thecloudtothousandsofcustomersandfacilitatingmorethanthreebillioncustomer interactionsannually.Since2001,Five9hasledthecloudrevolutionincontactcenters, deliveringsoftwaretohelporganizationsofeverysizetransitionfrompremise-based softwaretothecloud.Withitsextensiveexpertise,technology,andecosystemof partners,Five9deliverssecure,reliable,scalablecloudcontactcentersoftwaretohelp businessescreateexceptionalcustomerexperiences,increaseagentproductivityand delivertangibleresults.Formoreinformationvisitwww.five9.com. Trademarks Five9 Five9Logo Five9SoCoCareTM Five9ConnectTM 2 TechnicalRequirementsReferenceGuide'}
# {'page_number': 3, 'text': 'Contents\nWhat’sNew 8\nEnvironment and Security 10\nRMI Protocol 10\nRTPProtocol 10\nVoiceQuality Testing 11\nDigital Certificates 11\nDigiCertCertificates 12\nSupportedTLSProtocols 12\nTLSInboundCipherSuites 13\nTLS1.2 InboundCipherSuites 13\nTLS1.1 InboundCipherSuites 13\nTLSOutboundCipherSuites 13\nSetting theTLSProtocolsinYourBrowser 14\nChrome 14\nFirefox 15\nAppleSafari 15\nInternetExplorer 15\nFive9 SIP TrunkOptions 16\nPrivateSIPTrunksProvidedby Five9 ITSPProviders 16\nSIPTrunksProvidedby YourITSPProvider 17\nPrivateSIPTrunksforFive9 Gateway toCustomerGateway 17\nAgent and SupervisorApplications 18\nWeb-BasedApplicationRequirements 18\nWorkstations 18\nHardware 18\nWindowsPlatforms 18\nAppleMac Platforms 19\nChromebooks 19\nOperating Systems 19\nWebBrowsers 20\nWindowsPlatforms 20\nAppleMac Platforms 21\nWorkstationRequirementsforFive9 VideoEngagement 21\nHardware 21\n3 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'Contents WhatsNew 8 Environment and Security 10 RMI Protocol 10 RTPProtocol 10 VoiceQuality Testing 11 Digital Certificates 11 DigiCertCertificates 12 SupportedTLSProtocols 12 TLSInboundCipherSuites 13 TLS1.2 InboundCipherSuites 13 TLS1.1 InboundCipherSuites 13 TLSOutboundCipherSuites 13 Setting theTLSProtocolsinYourBrowser 14 Chrome 14 Firefox 15 AppleSafari 15 InternetExplorer 15 Five9 SIP TrunkOptions 16 PrivateSIPTrunksProvidedby Five9 ITSPProviders 16 SIPTrunksProvidedby YourITSPProvider 17 PrivateSIPTrunksforFive9 Gateway toCustomerGateway 17 Agent and SupervisorApplications 18 Web-BasedApplicationRequirements 18 Workstations 18 Hardware 18 WindowsPlatforms 18 AppleMac Platforms 19 Chromebooks 19 Operating Systems 19 WebBrowsers 20 WindowsPlatforms 20 AppleMac Platforms 21 WorkstationRequirementsforFive9 VideoEngagement 21 Hardware 21 3 TechnicalRequirementsReferenceGuide'}
# {'page_number': 4, 'text': 'WindowsRequirements 21\nAppleMac Requirements 22\nOperating Systems 22\nWebBrowsers 22\nWindowsPlatforms 22\nAppleMac Platforms 23\nMobileDevices 23\nVideoCameras 23\nFive9 AgentAssistRequirements 24\nUnifiedCommunications(UC) AdaptersforSkypeforBusiness 25\nVirtual DesktopInfrastructureRequirements 25\nHardware 25\nOperating Systems 26\nVirtual DesktopInfrastructure 26\nCitrix Platforms 26\nVMwarePlatforms 27\nJava-BasedApplicationRequirements 27\nHardware 28\nWindowsPlatforms 28\nAppleMac Platforms 28\nJava Runtime 29\nOperating Systems 29\nWindowsandMac (32- and64-Bit) 29\nFive9 AgentorSupervisorWorkstationUserAccessControl 29\nWebBrowsers 30\nWindowsPlatforms(32-bitversiononly) 30\nAppleMac Platforms 30\nFive9 Supervisor 30\nAppleiPad 30\nWorkstationRequirementsforSpreadsheetDashboards 31\nHeadsetforAgentsandSupervisors 31\nApplicationNotes 32\nWebPageSecurity andVisual IVR Scripts 32\nDashboards 32\nAgentDesktopPluswithDigital Engagement 33\nIntegratedAdministrationConsole 33\nFive9 Agent Integrations 34\nRequirementsforWeb-BasedAdapters 34\nWorkstationRequirements 35\nHardware 35\nWindowsPlatforms 35\nAppleMac Platforms 35\nOperating Systems 35\n4 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'WindowsRequirements 21 AppleMac Requirements 22 Operating Systems 22 WebBrowsers 22 WindowsPlatforms 22 AppleMac Platforms 23 MobileDevices 23 VideoCameras 23 Five9 AgentAssistRequirements 24 UnifiedCommunications(UC) AdaptersforSkypeforBusiness 25 Virtual DesktopInfrastructureRequirements 25 Hardware 25 Operating Systems 26 Virtual DesktopInfrastructure 26 Citrix Platforms 26 VMwarePlatforms 27 Java-BasedApplicationRequirements 27 Hardware 28 WindowsPlatforms 28 AppleMac Platforms 28 Java Runtime 29 Operating Systems 29 WindowsandMac (32- and64-Bit) 29 Five9 AgentorSupervisorWorkstationUserAccessControl 29 WebBrowsers 30 WindowsPlatforms(32-bitversiononly) 30 AppleMac Platforms 30 Five9 Supervisor 30 AppleiPad 30 WorkstationRequirementsforSpreadsheetDashboards 31 HeadsetforAgentsandSupervisors 31 ApplicationNotes 32 WebPageSecurity andVisual IVR Scripts 32 Dashboards 32 AgentDesktopPluswithDigital Engagement 33 IntegratedAdministrationConsole 33 Five9 Agent Integrations 34 RequirementsforWeb-BasedAdapters 34 WorkstationRequirements 35 Hardware 35 WindowsPlatforms 35 AppleMac Platforms 35 Operating Systems 35 4 TechnicalRequirementsReferenceGuide'}
# {'page_number': 5, 'text': 'WebBrowsers 36\nApplicationRequirements 37\nPlusAdapterforAgentDesktopToolkit 37\nPlusAdapterforSalesforce 37\nPlusAdapterforOracleServiceCloud 37\nPlusAdapterforNetSuite 37\nPlusAdapterforMicrosoftDynamics365 37\nPlusAdapterforZendesk 38\nPlusAdapterforServiceNow 38\nRequirementsforJava-BasedAdapters 38\nWorkstationRequirements 38\nHardware 38\nOperating Systems 38\nJava Requirements 39\nWebBrowsers 39\nApplicationRequirements 40\nFive9 AgentDesktopToolkit 40\nFive9 OpenCTI AdapterforSalesforce 40\nFive9 AdapterforNetSuite 40\nFive9 AdapterforOracleServiceCloud 40\nFive9 AdapterforVelocify 41\nFive9 CloudAPI WebServices(CustomIntegration) 41\nVerint SystemsRequirements 42\nWorkstationRequirements 42\nHardwareRequirements 42\nThird-Party SoftwareRequiredforAgentStations 43\nThird-Party SoftwareRequiredforBrowsing 45\nJRESettingsRequirements 45\nSupportedOperating Systems 47\nSupportedWebBrowsers 47\nInternetExplorer 47\nGoogleChrome 53\nBrowserRequirementsforVerintPlayer 56\nNetwork Requirements(LAN andWAN) 57\nFirewall Requirements 57\nCalabrioApplication Requirements 58\nDesktopRequirements 58\nWindowsOperating Systems 58\n.NET Framework 59\nWebBrowsers 59\nCaptureBandwidth 59\nAnalyticsandPlug-inExtensions 59\n5 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'WebBrowsers 36 ApplicationRequirements 37 PlusAdapterforAgentDesktopToolkit 37 PlusAdapterforSalesforce 37 PlusAdapterforOracleServiceCloud 37 PlusAdapterforNetSuite 37 PlusAdapterforMicrosoftDynamics365 37 PlusAdapterforZendesk 38 PlusAdapterforServiceNow 38 RequirementsforJava-BasedAdapters 38 WorkstationRequirements 38 Hardware 38 Operating Systems 38 Java Requirements 39 WebBrowsers 39 ApplicationRequirements 40 Five9 AgentDesktopToolkit 40 Five9 OpenCTI AdapterforSalesforce 40 Five9 AdapterforNetSuite 40 Five9 AdapterforOracleServiceCloud 40 Five9 AdapterforVelocify 41 Five9 CloudAPI WebServices(CustomIntegration) 41 Verint SystemsRequirements 42 WorkstationRequirements 42 HardwareRequirements 42 Third-Party SoftwareRequiredforAgentStations 43 Third-Party SoftwareRequiredforBrowsing 45 JRESettingsRequirements 45 SupportedOperating Systems 47 SupportedWebBrowsers 47 InternetExplorer 47 GoogleChrome 53 BrowserRequirementsforVerintPlayer 56 Network Requirements(LAN andWAN) 57 Firewall Requirements 57 CalabrioApplication Requirements 58 DesktopRequirements 58 WindowsOperating Systems 58 .NET Framework 59 WebBrowsers 59 CaptureBandwidth 59 AnalyticsandPlug-inExtensions 59 5 TechnicalRequirementsReferenceGuide'}
# {'page_number': 6, 'text': 'AntivirusReal-TimeScanning Exclusions 60\nFirewall Requirements 60\nStudioRequirements 61\nPublic InternetDomains 61\nWebServiceIntegrationIPAddresses 61\nSBC Public IPAddresses 63\nMedia ServerPublic IPAddresses 64\nNetwork 66\nFive9 Network Connectivity 66\nVirtual PrivateNetwork (VPN) 66\nVPN andQuality of Service(QOS) 66\nVPN andPrivateIPAddresses 67\nDirectConnectionOption 67\nRequiredDirectConnectionCriteria 67\nWebRTC 68\nFive9 Network Requirements(LAN andWAN) 69\nFive9 BandwidthRequirements 69\nFive9 Network Recommendations 70\nBandwidthRequirementsforFive9 VideoEngagementforAgents 71\nOtherVoIPServicesandPhones, Ports, IPAddressRanges, andNetwork Traffic 72\nFive9 InternetDomainsandIPAddresses 72\nFive9 IPAddressRanges 73\nFive9 IPAddressesforGlobal Voice 75\nFive9 IPAddressesforEmail 75\nFive9 Connectivity AssessmentTest 76\nFive9 IPAddressesforCallback API Integration 76\nFive9 InternetDomains 77\nCounterPathSoftphoneRequirements 80\nPerformanceDashboard 80\nSIPFirewall Note 81\nTCP/UDPPortRequirementsforSoftphoneCustomers 81\nTCP/UDPPortRequirementsforGateway Customers 82\nTCP/UDPPortRequirementsforPSTN Customers 83\nTCPandUDPPortsforConnectivity AssessmentTest 84\nTCPPortRequirementsforFTP/SFTP 84\nNetwork RequirementsforFive9 VideoEngagement 85\nPortRequirementsforEmail 85\nSOAPAPIs 86\nThird-Party Software 86\nFive9 Quality of Service(QoS) Features 86\nWorkstationQoSOption 86\nNetwork QoSOption 87\n6 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'AntivirusReal-TimeScanning Exclusions 60 Firewall Requirements 60 StudioRequirements 61 Public InternetDomains 61 WebServiceIntegrationIPAddresses 61 SBC Public IPAddresses 63 Media ServerPublic IPAddresses 64 Network 66 Five9 Network Connectivity 66 Virtual PrivateNetwork (VPN) 66 VPN andQuality of Service(QOS) 66 VPN andPrivateIPAddresses 67 DirectConnectionOption 67 RequiredDirectConnectionCriteria 67 WebRTC 68 Five9 Network Requirements(LAN andWAN) 69 Five9 BandwidthRequirements 69 Five9 Network Recommendations 70 BandwidthRequirementsforFive9 VideoEngagementforAgents 71 OtherVoIPServicesandPhones, Ports, IPAddressRanges, andNetwork Traffic 72 Five9 InternetDomainsandIPAddresses 72 Five9 IPAddressRanges 73 Five9 IPAddressesforGlobal Voice 75 Five9 IPAddressesforEmail 75 Five9 Connectivity AssessmentTest 76 Five9 IPAddressesforCallback API Integration 76 Five9 InternetDomains 77 CounterPathSoftphoneRequirements 80 PerformanceDashboard 80 SIPFirewall Note 81 TCP/UDPPortRequirementsforSoftphoneCustomers 81 TCP/UDPPortRequirementsforGateway Customers 82 TCP/UDPPortRequirementsforPSTN Customers 83 TCPandUDPPortsforConnectivity AssessmentTest 84 TCPPortRequirementsforFTP/SFTP 84 Network RequirementsforFive9 VideoEngagement 85 PortRequirementsforEmail 85 SOAPAPIs 86 Third-Party Software 86 Five9 Quality of Service(QoS) Features 86 WorkstationQoSOption 86 Network QoSOption 87 6 TechnicalRequirementsReferenceGuide'}
# {'page_number': 7, 'text': 'WorkforceOptimization Requirements 88\nAgentWorkstationRequirements 88\nVirtualizedAgentEnvironments 88\nHardware 89\nOperating Systems 89\nWebBrowsers 89\nSoftwareRequirements 90\nConfigurationRequirements 90\nFirewall Policies 91\nSupervisorWorkstationRequirements 91\nVirtualizedSupervisorEnvironments 91\nHardware 92\nOperating Systems 92\nWebBrowsers 92\nSoftwareRequirements 93\nConfigurationRequirements 93\nFirewall Policies 93\nBandwidthConsiderations 94\nUserMedia Playback 94\nScreenCaptureCacheTransmission 94\nExampleScreenCaptureCalculation 95\nReferences 96\nGlossary 96\nReferenceDocuments 98\n7 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'WorkforceOptimization Requirements 88 AgentWorkstationRequirements 88 VirtualizedAgentEnvironments 88 Hardware 89 Operating Systems 89 WebBrowsers 89 SoftwareRequirements 90 ConfigurationRequirements 90 Firewall Policies 91 SupervisorWorkstationRequirements 91 VirtualizedSupervisorEnvironments 91 Hardware 92 Operating Systems 92 WebBrowsers 92 SoftwareRequirements 93 ConfigurationRequirements 93 Firewall Policies 93 BandwidthConsiderations 94 UserMedia Playback 94 ScreenCaptureCacheTransmission 94 ExampleScreenCaptureCalculation 95 References 96 Glossary 96 ReferenceDocuments 98 7 TechnicalRequirementsReferenceGuide'}
# {'page_number': 8, 'text': 'What’s New\nThistableliststhechangesmadeinthelastsixreleasesofthisdocument:\nRelease Changes\nAugust2021 AddedFive9IPAddressesforCallbackAPIIntegration.\nl\nAddedinboundSFTPportinTCPPortRequirementsforFTP/SFTP.\nl\nUpdatedClearviewdomainslistinPerformanceDashboard.\nl\nUpdatedJavaRuntimeEnvironmentsupportinformationto1.8.0_30132-bit.\nl\nRemovedFive9NATIPAddressessection.\nl\nJuly2021 AddedFive9domainsforUS,CA,andEUregionsinFive9InternetDomains.\nl\nAddedFive9NATIPAddressessectioninFive9InternetDomainsandIPAddresses.\nl\nAddedStudioRequirements.\nl\nRemovedWindows7support.\nl\nJune2021 AddedEdgebrowsersupport:\nl\no UpdatedWebBrowsersinWeb-BasedApplicationRequirements\no UpdatedWebBrowsersinWorkstationRequirementsforFive9VideoEngagement\no UpdatedWebBrowsersinRequirementsforWeb-BasedAdapters\nAddedWorkforceOptimizationRequirements.\nl\nUpdatedJavaRuntimeEnvironmentsupportinformationto1.8.0_29132-bit.\nl\nMay2021 AddedbandwidthrequirementsforRingCentralinFive9BandwidthRequirements.\nl\nAddedMacOSBigSursupport:\nl\no UpdatedWorkstations,OperatingSystems,WebBrowsersinWeb-Based\nApplicationRequirements\no UpdatedWorkstations,OperatingSystems,WebBrowsers inWorkstation\nRequirementsforFive9VideoEngagement\no UpdatedWorkstations,OperatingSystems,WebBrowsersinRequirementsfor\nWeb-BasedAdapters\no UpdatedOperatingSystems,WebBrowsersinRequirementsforJava-Based\nAdapters\no AddedanoteaboutMacOSBigSurandSafari14inJava-BasedApplication\n8 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'Whats New Thistableliststhechangesmadeinthelastsixreleasesofthisdocument: Release Changes August2021 AddedFive9IPAddressesforCallbackAPIIntegration. l AddedinboundSFTPportinTCPPortRequirementsforFTP/SFTP. l UpdatedClearviewdomainslistinPerformanceDashboard. l UpdatedJavaRuntimeEnvironmentsupportinformationto1.8.0_30132-bit. l RemovedFive9NATIPAddressessection. l July2021 AddedFive9domainsforUS,CA,andEUregionsinFive9InternetDomains. l AddedFive9NATIPAddressessectioninFive9InternetDomainsandIPAddresses. l AddedStudioRequirements. l RemovedWindows7support. l June2021 AddedEdgebrowsersupport: l o UpdatedWebBrowsersinWeb-BasedApplicationRequirements o UpdatedWebBrowsersinWorkstationRequirementsforFive9VideoEngagement o UpdatedWebBrowsersinRequirementsforWeb-BasedAdapters AddedWorkforceOptimizationRequirements. l UpdatedJavaRuntimeEnvironmentsupportinformationto1.8.0_29132-bit. l May2021 AddedbandwidthrequirementsforRingCentralinFive9BandwidthRequirements. l AddedMacOSBigSursupport: l o UpdatedWorkstations,OperatingSystems,WebBrowsersinWeb-Based ApplicationRequirements o UpdatedWorkstations,OperatingSystems,WebBrowsers inWorkstation RequirementsforFive9VideoEngagement o UpdatedWorkstations,OperatingSystems,WebBrowsersinRequirementsfor Web-BasedAdapters o UpdatedOperatingSystems,WebBrowsersinRequirementsforJava-Based Adapters o AddedanoteaboutMacOSBigSurandSafari14inJava-BasedApplication 8 TechnicalRequirementsReferenceGuide'}
# {'page_number': 9, 'text': 'What’sNew\nRelease Changes\nRequirements\nUpdatedJavaRuntimeEnvironmentSupportinformationto1.8.0_28132-bit.\nl\nUpdatedIPaddressrangesforUS,Canada,andEUdatacentersinFive9IPAddress\nl\nRanges.\nUpdatedPortRequirementsforEmail.\nl\nUpdatedFive9ConnectivityAssessmentTest.\nl\nUpdatedbandwidthrequirementsforTeams,Zoom,andOffice@HandinFive9\nl\nBandwidthRequirements.\nMovedIPaddressesinformationfromVerintSystemsRequirementstoFive9IP\nl\nAddressRanges.\nMovedworkstation,browser,andoperatingsystemsinformationfromWebRTCto\nl\nWeb-BasedApplicationRequirements.\nApril2021 UpdatedVerintSystemsNetworkRequirements(LANandWAN)andWorkstation\nl\nRequirements.\nRemovednoteaboutdisablingThrottleJavaScripttimersinbackgroundinthe\nl\nChromebrowser.\nMarch2021 AddedFive9IPAddressesforEmail.\nl\nAddedFive9AgentAssistRequirements.\nl\nAddedURLforOffice@HandinFive9InternetDomains.\nl\nAddedAgentAssistandOffice@HandbandwidthrequirementsinFive9Bandwidth\nl\nRequirements.\nUpdatedDigitalCertificates\nl\nUpdatedworkstationrecommendationsinWebRTC.\nl\n9 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'WhatsNew Release Changes Requirements UpdatedJavaRuntimeEnvironmentSupportinformationto1.8.0_28132-bit. l UpdatedIPaddressrangesforUS,Canada,andEUdatacentersinFive9IPAddress l Ranges. UpdatedPortRequirementsforEmail. l UpdatedFive9ConnectivityAssessmentTest. l UpdatedbandwidthrequirementsforTeams,Zoom,andOffice@HandinFive9 l BandwidthRequirements. MovedIPaddressesinformationfromVerintSystemsRequirementstoFive9IP l AddressRanges. Movedworkstation,browser,andoperatingsystemsinformationfromWebRTCto l Web-BasedApplicationRequirements. April2021 UpdatedVerintSystemsNetworkRequirements(LANandWAN)andWorkstation l Requirements. RemovednoteaboutdisablingThrottleJavaScripttimersinbackgroundinthe l Chromebrowser. March2021 AddedFive9IPAddressesforEmail. l AddedFive9AgentAssistRequirements. l AddedURLforOffice@HandinFive9InternetDomains. l AddedAgentAssistandOffice@HandbandwidthrequirementsinFive9Bandwidth l Requirements. UpdatedDigitalCertificates l UpdatedworkstationrecommendationsinWebRTC. l 9 TechnicalRequirementsReferenceGuide'}
# {'page_number': 10, 'text': 'Environment and Security\nRMIProtocol\nRTPProtocol\nVoiceQualityTesting\nDigitalCertificates\nSupportedTLSProtocols\nImportant\nBeforeconfiguringyourorganization,besuretoobtainthemostcurrent\nsecurityandlegalinformationrelevanttoyourbusiness.Forexample,youcan\nstartbyconsultingtheFive9Enterprise-ReadySecuritypagesandyourlegal\nadvisor.\nRMI Protocol\nFive9usesthesecureRemoteMethodInvocation(RMI)protocolfortheJava-to-Java\ncommunicationsbetweentheFive9clientapplicationsandVirtualContactCenter\nplatform.TheRMItrafficistransmittedoutofthefirewallthroughopenTCPportsby\nusingtheTLSprotocol.\nRTP Protocol\nVoicetrafficforVCCistransferredusingtheReal-TimeTransportProtocol(RTP).TheRTP\ndownload(inbound)streamsthevoicepacketssentfromtheFive9datacentertothe\nagent’ssoftphone.Thevoicepacketsthatrepresentthecaller’svoiceupstream\n(outbound)arerebuiltinthesoftphone.Thevoicepacketsaresentfromtheagent’s\nsoftphonetotheFive9datacenterstoberebuiltandplayedbacktothecallerasthe\nagent’svoice.ThevoicepackettransferusesUserDatagramProtocol(UDP)whichis\nfasterandmoreefficientthanTCPfortime-sensitiveapplications,suchasVoIP.\nInterceptingtheRTPstreamtolisteninonalegofthecallwouldrequirelocalnetwork\naccesstosuccessfullyrebuildthepacketsintoanintelligiblevoicestream.\n10 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'Environment and Security RMIProtocol RTPProtocol VoiceQualityTesting DigitalCertificates SupportedTLSProtocols Important Beforeconfiguringyourorganization,besuretoobtainthemostcurrent securityandlegalinformationrelevanttoyourbusiness.Forexample,youcan startbyconsultingtheFive9Enterprise-ReadySecuritypagesandyourlegal advisor. RMI Protocol Five9usesthesecureRemoteMethodInvocation(RMI)protocolfortheJava-to-Java communicationsbetweentheFive9clientapplicationsandVirtualContactCenter platform.TheRMItrafficistransmittedoutofthefirewallthroughopenTCPportsby usingtheTLSprotocol. RTP Protocol VoicetrafficforVCCistransferredusingtheReal-TimeTransportProtocol(RTP).TheRTP download(inbound)streamsthevoicepacketssentfromtheFive9datacentertothe agentssoftphone.Thevoicepacketsthatrepresentthecallersvoiceupstream (outbound)arerebuiltinthesoftphone.Thevoicepacketsaresentfromtheagents softphonetotheFive9datacenterstoberebuiltandplayedbacktothecallerasthe agentsvoice.ThevoicepackettransferusesUserDatagramProtocol(UDP)whichis fasterandmoreefficientthanTCPfortime-sensitiveapplications,suchasVoIP. InterceptingtheRTPstreamtolisteninonalegofthecallwouldrequirelocalnetwork accesstosuccessfullyrebuildthepacketsintoanintelligiblevoicestream. 10 TechnicalRequirementsReferenceGuide'}
# {'page_number': 11, 'text': 'EnvironmentandSecurity VoiceQualityTesting\nVoice Quality Testing\nFive9ConnectivityAssessmentTest(CAT)usesPort80and8081.YoucanrunVoIP\nqualitytestsathttps://www.five9.com/catfromasingleagentworkstationateach\nlocation.Donotrunmultipletestssimultaneously.\nDigital Certificates\nTocommunicatesecurelywithFive9VCC,usersmayneedtoinstallontheirworkstation\nthesecertificatesfromthecertificate-issuingauthoritiesthatFive9uses.\nImportant\nFollowingindustrybestpracticesandcertificateauthorities(CA),Five9willno\nlongertrustorcertifysecureTLSconnectionsbasedonthecertificatesissuedby\nSymantecRootCertificateAuthority(CA)listedbelow.Ifyoudonotreplace\nthesedistrustedcertificates,yourFive9integrationmaynotwork.Therefore,\nFive9highlyrecommendsthatyoureplacethedistrustedcertificateswiththe\ncertificatesissuedbyDigiCert.\nFive9willnolongertrustthefollowingSymantecRootCAs:\nCN=GeoTrustGlobalCA,O=GeoTrustInc.,C=US\nl\nCN=GeoTrustPrimaryCertificationAuthority,O=GeoTrustInc.,C=US\nl\nCN=GeoTrustPrimaryCertificationAuthority-G2,\nl\nOU=(c)2007GeoTrustInc.-Forauthorizeduseonly,O=GeoTrustInc.,C=US\nCN=GeoTrustPrimaryCertificationAuthority-G3,\nl\nOU=(c)2008GeoTrustInc.-Forauthorizeduseonly,O=GeoTrustInc.,C=US\nCN=GeoTrustUniversalCA,O=GeoTrustInc.,C=US\nl\nCN=thawtePrimaryRootCA,OU="(c)2006thawte,Inc.-Forauthorizeduse\nl\nonly",\nOU=CertificationServicesDivision,O="thawte,Inc.",C=US\nCN=thawtePrimaryRootCA-G2,OU="(c)2007thawte,Inc.-Forauthorizeduse\nl\nonly",\nO="thawte,Inc.",C=US\nCN=thawtePrimaryRootCA-G3,OU="(c)2008thawte,Inc.-Forauthorizeduse\nl\nonly",\nOU=CertificationServicesDivision,O="thawte,Inc.",C=US\nEMAILADDRESS=premium-server@thawte.com,CN=ThawtePremiumServerCA,\nl\nOU=CertificationServicesDivision,O=ThawteConsultingcc,\nL=CapeTown,ST=WesternCape,C=ZA\n11 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'EnvironmentandSecurity VoiceQualityTesting Voice Quality Testing Five9ConnectivityAssessmentTest(CAT)usesPort80and8081.YoucanrunVoIP qualitytestsathttps://www.five9.com/catfromasingleagentworkstationateach location.Donotrunmultipletestssimultaneously. Digital Certificates TocommunicatesecurelywithFive9VCC,usersmayneedtoinstallontheirworkstation thesecertificatesfromthecertificate-issuingauthoritiesthatFive9uses. Important Followingindustrybestpracticesandcertificateauthorities(CA),Five9willno longertrustorcertifysecureTLSconnectionsbasedonthecertificatesissuedby SymantecRootCertificateAuthority(CA)listedbelow.Ifyoudonotreplace thesedistrustedcertificates,yourFive9integrationmaynotwork.Therefore, Five9highlyrecommendsthatyoureplacethedistrustedcertificateswiththe certificatesissuedbyDigiCert. Five9willnolongertrustthefollowingSymantecRootCAs: CN=GeoTrustGlobalCA,O=GeoTrustInc.,C=US l CN=GeoTrustPrimaryCertificationAuthority,O=GeoTrustInc.,C=US l CN=GeoTrustPrimaryCertificationAuthority-G2, l OU=(c)2007GeoTrustInc.-Forauthorizeduseonly,O=GeoTrustInc.,C=US CN=GeoTrustPrimaryCertificationAuthority-G3, l OU=(c)2008GeoTrustInc.-Forauthorizeduseonly,O=GeoTrustInc.,C=US CN=GeoTrustUniversalCA,O=GeoTrustInc.,C=US l CN=thawtePrimaryRootCA,OU="(c)2006thawte,Inc.-Forauthorizeduse l only", OU=CertificationServicesDivision,O="thawte,Inc.",C=US CN=thawtePrimaryRootCA-G2,OU="(c)2007thawte,Inc.-Forauthorizeduse l only", O="thawte,Inc.",C=US CN=thawtePrimaryRootCA-G3,OU="(c)2008thawte,Inc.-Forauthorizeduse l only", OU=CertificationServicesDivision,O="thawte,Inc.",C=US EMAILADDRESS=premium-server@thawte.com,CN=ThawtePremiumServerCA, l OU=CertificationServicesDivision,O=ThawteConsultingcc, L=CapeTown,ST=WesternCape,C=ZA 11 TechnicalRequirementsReferenceGuide'}
# {'page_number': 12, 'text': 'EnvironmentandSecurity SupportedTLSProtocols\nOU=VeriSignTrustNetwork,OU="(c)1998VeriSign,Inc.-Forauthorizeduse\nl\nonly",\nOU=Class2PublicPrimaryCertificationAuthority-G2,O="VeriSign,Inc.",C=US\nOU=Class3PublicPrimaryCertificationAuthority,O="VeriSign,Inc.",C=US\nl\nOU=VeriSignTrustNetwork,OU="(c)1998VeriSign,Inc.-Forauthorizeduse\nl\nonly",\nOU=Class3PublicPrimaryCertificationAuthority-G2,O="VeriSign,Inc.",C=US\nCN=VeriSignClass3PublicPrimaryCertificationAuthority-G3,\nl\nOU="(c)1999VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust\nNetwork,\nO="VeriSign,Inc.",C=US\nCN=VeriSignClass3PublicPrimaryCertificationAuthority-G4,\nl\nOU="(c)2007VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust\nNetwork,\nO="VeriSign,Inc.",C=US\nCN=VeriSignClass3PublicPrimaryCertificationAuthority-G5,\nl\nOU="(c)2006VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust\nNetwork,\nO="VeriSign,Inc.",C=US\nCN=VeriSignUniversalRootCertificationAuthority,\nl\nOU="(c)2008VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust\nNetwork,\nO="VeriSign,Inc.",C=US\nDigiCert Certificates\nCertificate Link\nHigh https://cacerts.digicert.com/DigiCertHighAssuranceEVRootCA.crt.pem\nAssuranceEV\nRootCA\nGlobalRoot https://cacerts.digicert.com/DigiCertGlobalRootCA.crt.pem\nCA\nSupported TLS Protocols\nFive9doesnotacceptunencryptedAPIconnections.Whendevelopingacustomweb\nservicetocommunicatewiththeFive9API,ensurethatyourwebserviceusesthese\nsecurityprotocolsandthatyouusethewebbrowsersversionssupportedbyFive9.If\n12 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'EnvironmentandSecurity SupportedTLSProtocols OU=VeriSignTrustNetwork,OU="(c)1998VeriSign,Inc.-Forauthorizeduse l only", OU=Class2PublicPrimaryCertificationAuthority-G2,O="VeriSign,Inc.",C=US OU=Class3PublicPrimaryCertificationAuthority,O="VeriSign,Inc.",C=US l OU=VeriSignTrustNetwork,OU="(c)1998VeriSign,Inc.-Forauthorizeduse l only", OU=Class3PublicPrimaryCertificationAuthority-G2,O="VeriSign,Inc.",C=US CN=VeriSignClass3PublicPrimaryCertificationAuthority-G3, l OU="(c)1999VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust Network, O="VeriSign,Inc.",C=US CN=VeriSignClass3PublicPrimaryCertificationAuthority-G4, l OU="(c)2007VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust Network, O="VeriSign,Inc.",C=US CN=VeriSignClass3PublicPrimaryCertificationAuthority-G5, l OU="(c)2006VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust Network, O="VeriSign,Inc.",C=US CN=VeriSignUniversalRootCertificationAuthority, l OU="(c)2008VeriSign,Inc.-Forauthorizeduseonly",OU=VeriSignTrust Network, O="VeriSign,Inc.",C=US DigiCert Certificates Certificate Link High https://cacerts.digicert.com/DigiCertHighAssuranceEVRootCA.crt.pem AssuranceEV RootCA GlobalRoot https://cacerts.digicert.com/DigiCertGlobalRootCA.crt.pem CA Supported TLS Protocols Five9doesnotacceptunencryptedAPIconnections.Whendevelopingacustomweb servicetocommunicatewiththeFive9API,ensurethatyourwebserviceusesthese securityprotocolsandthatyouusethewebbrowsersversionssupportedbyFive9.If 12 TechnicalRequirementsReferenceGuide'}
# {'page_number': 13, 'text': 'EnvironmentandSecurity SupportedTLSProtocols\nyourenvironmentusesproxyservers,thesemustsupportthesecureWebSocket(WSS)\nprotocolfordesktopandnetworkproxies.\nSecurity Protocol Notes\nTLS TransportLayerSecurityprotocol.TLS1.2andTLS1.1are\nsupportedforinboundandoutboundtraffic.\nTLSCipherSuite Minimumof128-bitencryptionisrequired.\nWSS SecureWebSocket(WSS)protocolusesTLSencryption.\nDiffie-HellmanKey Mustbegreaterthanorequalto2048.\nTLS Inbound Cipher Suites\nThefollowingarethesupportedTLSinboundciphersuites.Toverifythatyourservers\nsupporttheseciphers,gotoSSLServerTest.\nTLS 1.2 Inbound Cipher Suites\nTLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384(0xc030)\nl\nTLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256(0xc02f)\nl\nTLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384(0xc028)\nl\nTLS_ECDHE_RSA_WITH_AES_256_CBC_SHA(0xc014)\nl\nTLS_ECDHE_RSA_WITH_AES_128_CBC_SHA256(0xc027)\nl\nTLS_ECDHE_RSA_WITH_AES_128_CBC_SHA(0xc013)\nl\nTLS 1.1 Inbound Cipher Suites\nTLS_ECDHE_RSA_WITH_AES_256_CBC_SHA(0xc014)\nl\nTLS_ECDHE_RSA_WITH_AES_128_CBC_SHA(0xc013)\nl\nTLS Outbound Cipher Suites\nThefollowingarethesupportedTLS1.2outboundciphersuites.Toverifythatyour\nserverssupporttheseciphers,gotoSSLServerTest.\nTLS_ECDHE_ECDSA_WITH_AES_256_CBC_SHA384(0xc024)\nl\nTLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384(0xc028)\nl\nTLS_ECDH_ECDSA_WITH_AES_256_CBC_SHA384(0xc026)\nl\n13 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'EnvironmentandSecurity SupportedTLSProtocols yourenvironmentusesproxyservers,thesemustsupportthesecureWebSocket(WSS) protocolfordesktopandnetworkproxies. Security Protocol Notes TLS TransportLayerSecurityprotocol.TLS1.2andTLS1.1are supportedforinboundandoutboundtraffic. TLSCipherSuite Minimumof128-bitencryptionisrequired. WSS SecureWebSocket(WSS)protocolusesTLSencryption. Diffie-HellmanKey Mustbegreaterthanorequalto2048. TLS Inbound Cipher Suites ThefollowingarethesupportedTLSinboundciphersuites.Toverifythatyourservers supporttheseciphers,gotoSSLServerTest. TLS 1.2 Inbound Cipher Suites TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384(0xc030) l TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256(0xc02f) l TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384(0xc028) l TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA(0xc014) l TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA256(0xc027) l TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA(0xc013) l TLS 1.1 Inbound Cipher Suites TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA(0xc014) l TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA(0xc013) l TLS Outbound Cipher Suites ThefollowingarethesupportedTLS1.2outboundciphersuites.Toverifythatyour serverssupporttheseciphers,gotoSSLServerTest. TLS_ECDHE_ECDSA_WITH_AES_256_CBC_SHA384(0xc024) l TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384(0xc028) l TLS_ECDH_ECDSA_WITH_AES_256_CBC_SHA384(0xc026) l 13 TechnicalRequirementsReferenceGuide'}
# {'page_number': 14, 'text': 'EnvironmentandSecurity SupportedTLSProtocols\nTLS_ECDH_RSA_WITH_AES_256_CBC_SHA384(0xc02a)\nl\nTLS_ECDHE_ECDSA_WITH_AES_256_CBC_SHA(0xc00a)\nl\nTLS_ECDHE_RSA_WITH_AES_256_CBC_SHA(0xc014)\nl\nTLS_ECDH_ECDSA_WITH_AES_256_CBC_SHA(0xc005)\nl\nTLS_ECDH_RSA_WITH_AES_256_CBC_SHA(0xc00f)\nl\nTLS_ECDHE_ECDSA_WITH_AES_128_CBC_SHA256(0xc023)\nl\nTLS_ECDHE_RSA_WITH_AES_128_CBC_SHA256(0xc027)\nl\nTLS_ECDH_ECDSA_WITH_AES_128_CBC_SHA256(0xc025)\nl\nTLS_ECDH_RSA_WITH_AES_128_CBC_SHA256(0xc029)\nl\nTLS_ECDHE_ECDSA_WITH_AES_128_CBC_SHA(0xc009)\nl\nTLS_ECDHE_RSA_WITH_AES_128_CBC_SHA(0xc013)\nl\nTLS_ECDH_ECDSA_WITH_AES_128_CBC_SHA(0xc004)\nl\nTLS_ECDH_RSA_WITH_AES_128_CBC_SHA(0xc00e)\nl\nTLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384(0xc02c)\nl\nTLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256(0xc02b)\nl\nTLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384(0xc030)\nl\nTLS_ECDH_ECDSA_WITH_AES_256_GCM_SHA384(0xc02e)\nl\nTLS_ECDH_RSA_WITH_AES_256_GCM_SHA384(0xc032)\nl\nTLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256(0xc02f)\nl\nTLS_ECDH_ECDSA_WITH_AES_128_GCM_SHA256(0xc02d)\nl\nTLS_ECDH_RSA_WITH_AES_128_GCM_SHA256(0xc031)\nl\nTLS_EMPTY_RENEGOTIATION_INFO_SCSV(0x00ff)\nl\nSetting the TLS Protocols in Your Browser\nEnableTLS1.1andTLS1.2encryptionprotocolsinyourbrowsersecuritysettings.\nImportant\nFollowthesestepsonlyifinstructedtodosobyyouradministrator.\nChrome\n1 OpenChrome.\n2 Onyourkeyboard,pressAltFandselectSettings.\n3 Atthebottomofthepage,clickAdvanced.\n4 ScrolldowntotheSystem sectionandclickOpen proxy settings.\n14 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'EnvironmentandSecurity SupportedTLSProtocols TLS_ECDH_RSA_WITH_AES_256_CBC_SHA384(0xc02a) l TLS_ECDHE_ECDSA_WITH_AES_256_CBC_SHA(0xc00a) l TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA(0xc014) l TLS_ECDH_ECDSA_WITH_AES_256_CBC_SHA(0xc005) l TLS_ECDH_RSA_WITH_AES_256_CBC_SHA(0xc00f) l TLS_ECDHE_ECDSA_WITH_AES_128_CBC_SHA256(0xc023) l TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA256(0xc027) l TLS_ECDH_ECDSA_WITH_AES_128_CBC_SHA256(0xc025) l TLS_ECDH_RSA_WITH_AES_128_CBC_SHA256(0xc029) l TLS_ECDHE_ECDSA_WITH_AES_128_CBC_SHA(0xc009) l TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA(0xc013) l TLS_ECDH_ECDSA_WITH_AES_128_CBC_SHA(0xc004) l TLS_ECDH_RSA_WITH_AES_128_CBC_SHA(0xc00e) l TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384(0xc02c) l TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256(0xc02b) l TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384(0xc030) l TLS_ECDH_ECDSA_WITH_AES_256_GCM_SHA384(0xc02e) l TLS_ECDH_RSA_WITH_AES_256_GCM_SHA384(0xc032) l TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256(0xc02f) l TLS_ECDH_ECDSA_WITH_AES_128_GCM_SHA256(0xc02d) l TLS_ECDH_RSA_WITH_AES_128_GCM_SHA256(0xc031) l TLS_EMPTY_RENEGOTIATION_INFO_SCSV(0x00ff) l Setting the TLS Protocols in Your Browser EnableTLS1.1andTLS1.2encryptionprotocolsinyourbrowsersecuritysettings. Important Followthesestepsonlyifinstructedtodosobyyouradministrator. Chrome 1 OpenChrome. 2 Onyourkeyboard,pressAltFandselectSettings. 3 Atthebottomofthepage,clickAdvanced. 4 ScrolldowntotheSystem sectionandclickOpen proxy settings. 14 TechnicalRequirementsReferenceGuide'}
# {'page_number': 15, 'text': 'EnvironmentandSecurity SupportedTLSProtocols\n5 FromtheInternetPropertiesmenu,selecttheAdvancedtab.\n6 IntheSecuritysection,enableUseTLS 1.1andUseTLS 1.2.\n7 ClickApplyandOK,andrestartChrome.\nFirefox\n1 IntheFirefoxaddressbar,typeabout:configandpressEnter.\n2 ClickAccepttheRiskand Continue.\n3 Inthesearchfield,typetls.\n4 Fromthesearchresults,double-clicksecurity.tls.version.min.\n5 ForTLS1.1,enter2.\n6 ClickOK.\n7 Closethetab,andrestartFirefox.\nApple Safari\nTLS1.1andTLS1.2areautomaticallyenabledinversion9orgreater.\nInternet Explorer\n1 ClicktheToolsgeariconnearthetoprightcorner,andselectInternetoptions.\n2 SelecttheAdvancedtab.\n3 Scrolltotheendofthelist,andenableUseTLS 1.1andUseTLS 1.2.\n4 ClickOK,andrestartInternetExplorer.\n15 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'EnvironmentandSecurity SupportedTLSProtocols 5 FromtheInternetPropertiesmenu,selecttheAdvancedtab. 6 IntheSecuritysection,enableUseTLS 1.1andUseTLS 1.2. 7 ClickApplyandOK,andrestartChrome. Firefox 1 IntheFirefoxaddressbar,typeabout:configandpressEnter. 2 ClickAccepttheRiskand Continue. 3 Inthesearchfield,typetls. 4 Fromthesearchresults,double-clicksecurity.tls.version.min. 5 ForTLS1.1,enter2. 6 ClickOK. 7 Closethetab,andrestartFirefox. Apple Safari TLS1.1andTLS1.2areautomaticallyenabledinversion9orgreater. Internet Explorer 1 ClicktheToolsgeariconnearthetoprightcorner,andselectInternetoptions. 2 SelecttheAdvancedtab. 3 Scrolltotheendofthelist,andenableUseTLS 1.1andUseTLS 1.2. 4 ClickOK,andrestartInternetExplorer. 15 TechnicalRequirementsReferenceGuide'}
# {'page_number': 16, 'text': 'Five9 SIP Trunk Options\nSIPtrunksareVoIP-basedcarrierservicesofferedbyanInternetTelephonyService\nProvider(ITSP)thatusestheSIPprotocoltosetupcommunicationsbetweenthePSTN\nnetworkandinbound,outboundand/orblendedcallsbyFive9Agents.SIPtrunks\nsupportalldomestic,International,andtoll-freeservices.\nPrivateSIPTrunksProvidedbyFive9ITSPProviders\nSIPTrunksProvidedbyYourITSPProvider\nPrivateSIPTrunksforFive9GatewaytoCustomerGateway\nImportant\nToensurethatyourbusinessisnotaffectedduringdatacentermigrations,be\nsuretoconfigurearedundantdatacenterregardlessofthedatacenterthat\nyouuse.Forexample,ifyourprimarydatacenterisATL(Atlanta),youralternate\ndatacenterisSCL(SantaClara).\nPrivate SIP Trunks Provided by Five9 ITSP\nProviders\nThisserviceoriginatesintheFive9datacenterandisconnectedtothePSTNnetwork.\nYoudonotneedtoconfigureanything.\n16 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'Five9 SIP Trunk Options SIPtrunksareVoIP-basedcarrierservicesofferedbyanInternetTelephonyService Provider(ITSP)thatusestheSIPprotocoltosetupcommunicationsbetweenthePSTN networkandinbound,outboundand/orblendedcallsbyFive9Agents.SIPtrunks supportalldomestic,International,andtoll-freeservices. PrivateSIPTrunksProvidedbyFive9ITSPProviders SIPTrunksProvidedbyYourITSPProvider PrivateSIPTrunksforFive9GatewaytoCustomerGateway Important Toensurethatyourbusinessisnotaffectedduringdatacentermigrations,be suretoconfigurearedundantdatacenterregardlessofthedatacenterthat youuse.Forexample,ifyourprimarydatacenterisATL(Atlanta),youralternate datacenterisSCL(SantaClara). Private SIP Trunks Provided by Five9 ITSP Providers ThisserviceoriginatesintheFive9datacenterandisconnectedtothePSTNnetwork. Youdonotneedtoconfigureanything. 16 TechnicalRequirementsReferenceGuide'}
# {'page_number': 17, 'text': 'Five9SIPTrunkOptions SIPTrunksProvidedbyYourITSPProvider\nSIP Trunks Provided by Your ITSP Provider\nYourITSPisconnectedtotheFive9SBCsintheFive9datacenters.Tosuccessfully\nconfigure,test,andturnuptheSIPtrunk,youmustcompleteandreturnthe\ninstallationchecklisttoFive9.\nPrivate SIP Trunks for Five9 Gateway to\nCustomer Gateway\nIfyourenterprisealreadyhasorisconsideringaSIPInfrastructure,suchasaSBC,proxy\nserver,orSIPserver,youmayalsoselectthegateway-to-gatewayoption.NewSIP\ntrunksareinstalledduringtheFive9setup.\nAgateway,suchasAVAYA,CISCO,orAsterisk,enablesyoutoconnecttoFive9withSIP\ntrunksacrosstheInternetand/orthroughaVPNorDirectConnectOption.\n17 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'Five9SIPTrunkOptions SIPTrunksProvidedbyYourITSPProvider SIP Trunks Provided by Your ITSP Provider YourITSPisconnectedtotheFive9SBCsintheFive9datacenters.Tosuccessfully configure,test,andturnuptheSIPtrunk,youmustcompleteandreturnthe installationchecklisttoFive9. Private SIP Trunks for Five9 Gateway to Customer Gateway IfyourenterprisealreadyhasorisconsideringaSIPInfrastructure,suchasaSBC,proxy server,orSIPserver,youmayalsoselectthegateway-to-gatewayoption.NewSIP trunksareinstalledduringtheFive9setup. Agateway,suchasAVAYA,CISCO,orAsterisk,enablesyoutoconnecttoFive9withSIP trunksacrosstheInternetand/orthroughaVPNorDirectConnectOption. 17 TechnicalRequirementsReferenceGuide'}
# {'page_number': 18, 'text': 'Agent and Supervisor Applications\nWeb-BasedApplicationRequirements\nFive9AgentAssistRequirements\nUnifiedCommunications(UC)AdaptersforSkypeforBusiness\nVirtualDesktopInfrastructureRequirements\nJava-BasedApplicationRequirements\nHeadsetforAgentsandSupervisors\nApplicationNotes\nWeb-Based Application Requirements\nTheserequirementsarespecifictoFive9AgentDesktopPlusandSupervisorPlus,which\narebrowserbased.\nIfusershaveadditionalapplications,besurethateachcomputerhassufficient\nhardware,afasterprocessor,andadditionalRAMtosupportallapplicationsinaddition\ntotheFive9applications.\nTocommunicatewithFive9,AgentDesktopPlususesstandardsecurityprotocols\nHTTPSandSecureWebSocket(WSS),whichisrequiredforproxyservers.SeeSupported\nTLSProtocolsfordetails.\nWorkstations\nWorkstationRequirementsforFive9VideoEngagement\nWorkstations\nHardware\nWindows Platforms\nComponent Minimum Version orValue Recommended\nProcessor IntelCorei5-4440,CPU2.10GHz IntelCorei7-4770,CPU3.40GHZ\n18 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'Agent and Supervisor Applications Web-BasedApplicationRequirements Five9AgentAssistRequirements UnifiedCommunications(UC)AdaptersforSkypeforBusiness VirtualDesktopInfrastructureRequirements Java-BasedApplicationRequirements HeadsetforAgentsandSupervisors ApplicationNotes Web-Based Application Requirements TheserequirementsarespecifictoFive9AgentDesktopPlusandSupervisorPlus,which arebrowserbased. Ifusershaveadditionalapplications,besurethateachcomputerhassufficient hardware,afasterprocessor,andadditionalRAMtosupportallapplicationsinaddition totheFive9applications. TocommunicatewithFive9,AgentDesktopPlususesstandardsecurityprotocols HTTPSandSecureWebSocket(WSS),whichisrequiredforproxyservers.SeeSupported TLSProtocolsfordetails. Workstations WorkstationRequirementsforFive9VideoEngagement Workstations Hardware Windows Platforms Component Minimum Version orValue Recommended Processor IntelCorei5-4440,CPU2.10GHz IntelCorei7-4770,CPU3.40GHZ 18 TechnicalRequirementsReferenceGuide'}
# {'page_number': 19, 'text': 'AgentandSupervisorApplications Web-BasedApplicationRequirements\nComponent Minimum Version orValue Recommended\nWithSecureRTP,minimum\nrequirementsincreasetoIntel\nPentiumIV2.66GHZorgreater.\nMemory 8GB 16GB\nScreenResolution 1024x768 1024x768\nApple Mac Platforms\nComponent Minimum Version orValue Recommended\nProcessor IntelCorei5,1.7GHz IntelCorei7,2.3GHz\nl l\nAppleM1 AppleM1\nl l\nMemory 8GB 16GB\nChromebooks\nChromebooksaresupportedforWebRTConly.TheFive9Softphoneplug-incannotbe\ninstalledontheseproducts.\nComponent Minimum Version orValue\nProcessor IntelCorei5\nMemory 8GB\nOperating Systems\nOperating System Version Supported\nWindows32-and64-Bit Windows8.1,8.1Professional\nl\nWindows10,Professional,andAnniversaryUpdate\nl\nSeenotesaboutspecificWindowsissues.\nAppleMac Version10.14Mojave\nl\nVersion10.15Catalina\nl\nVersion11.2.3BigSur\nl\nChrome Versions89.0.4389.130,90.0.4430.215\nl\n19 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'AgentandSupervisorApplications Web-BasedApplicationRequirements Component Minimum Version orValue Recommended WithSecureRTP,minimum requirementsincreasetoIntel PentiumIV2.66GHZorgreater. Memory 8GB 16GB ScreenResolution 1024x768 1024x768 Apple Mac Platforms Component Minimum Version orValue Recommended Processor IntelCorei5,1.7GHz IntelCorei7,2.3GHz l l AppleM1 AppleM1 l l Memory 8GB 16GB Chromebooks ChromebooksaresupportedforWebRTConly.TheFive9Softphoneplug-incannotbe installedontheseproducts. Component Minimum Version orValue Processor IntelCorei5 Memory 8GB Operating Systems Operating System Version Supported Windows32-and64-Bit Windows8.1,8.1Professional l Windows10,Professional,andAnniversaryUpdate l SeenotesaboutspecificWindowsissues. AppleMac Version10.14Mojave l Version10.15Catalina l Version11.2.3BigSur l Chrome Versions89.0.4389.130,90.0.4430.215 l 19 TechnicalRequirementsReferenceGuide'}
# {'page_number': 20, 'text': 'AgentandSupervisorApplications Web-BasedApplicationRequirements\nNote\nSpecificWindowsissues:\nWindowsMediaPlayerisnotinstalledbydefaultsotherequiredMP3\nl\ncodecsareabsent.Asaresult,soundalertsandvoicemailrecordings\ncannotbeplayedinInternetExplorerandFirefox.Toresolvethisissue,\ninstalltheappropriateupdateforyourplatform:\no Windows8NandKN\no Windows8.1NandKN\no Windows10NandKN\nWorkstationUserAccessPrivileges\nl\nUserAccessControl(UAC)canremainenabledduringinstallation.VCC\nusersmust,ataminimum,bestandardusersontheirWindows\nworkstation.\no Windows8and8.1\no Windows10and10Pro\nWeb Browsers\nWindows Platforms\nBrowser Version\nGoogleChrome™ Mostrecentthreestableversions.GoogleChromeisautomatically\nupdated.Five9makeseveryefforttotestandsupportthemost\nrecentversion.\nFive9supports32-and64-bitversionsoftheChromebrowser.\nFirefox Mostrecentthreestableversions.\nFive9supports32-and64-bitversionsoftheFirefoxbrowser.1\nMicrosoftEdge Mostrecentthreestableversions.\nFive9supportsMicrosoftEdgebasedonChromium.MicrosoftEdge\nissupportedonWindows10Professional64-bit.Forinformationon\ndownloadingandinstallingEdgebasedonChromium,seethe\nMicrosoftEdgedocumentation.\nImportant:TheFive9Softphoneadapterisnotsupportedon\npreviousversionsofEdge.\nInternetExplorer Version11.\nImportant: Ifyourcustomersuseversion10orlower,theydonot\n20 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'AgentandSupervisorApplications Web-BasedApplicationRequirements Note SpecificWindowsissues: WindowsMediaPlayerisnotinstalledbydefaultsotherequiredMP3 l codecsareabsent.Asaresult,soundalertsandvoicemailrecordings cannotbeplayedinInternetExplorerandFirefox.Toresolvethisissue, installtheappropriateupdateforyourplatform: o Windows8NandKN o Windows8.1NandKN o Windows10NandKN WorkstationUserAccessPrivileges l UserAccessControl(UAC)canremainenabledduringinstallation.VCC usersmust,ataminimum,bestandardusersontheirWindows workstation. o Windows8and8.1 o Windows10and10Pro Web Browsers Windows Platforms Browser Version GoogleChromeTM Mostrecentthreestableversions.GoogleChromeisautomatically updated.Five9makeseveryefforttotestandsupportthemost recentversion. Five9supports32-and64-bitversionsoftheChromebrowser. Firefox Mostrecentthreestableversions. Five9supports32-and64-bitversionsoftheFirefoxbrowser.1 MicrosoftEdge Mostrecentthreestableversions. Five9supportsMicrosoftEdgebasedonChromium.MicrosoftEdge issupportedonWindows10Professional64-bit.Forinformationon downloadingandinstallingEdgebasedonChromium,seethe MicrosoftEdgedocumentation. Important:TheFive9Softphoneadapterisnotsupportedon previousversionsofEdge. InternetExplorer Version11. Important: Ifyourcustomersuseversion10orlower,theydonot 20 TechnicalRequirementsReferenceGuide'}
# {'page_number': 21, 'text': 'AgentandSupervisorApplications Web-BasedApplicationRequirements\nBrowser Version\nseepreviewandproactivechat,email,andsurveyconsoleoffers.\nInsteadtheyseeamessagerecommendingthattheyupgradeto\nversion11.Inthatcase,recommendthattheyenablelocalstorage:\nTools>InternetOptions>Advanced>Security>EnableDOM\nstorage.\n1Five9doesnotrecommendusingFirefoxforWebRTCwhenmultipletabsareused.\nApple Mac Platforms\nMacOSXis64-bitonly.\nBrowser Version\nGoogleChrome™ Mostrecentthreestableversions.GoogleChromeisautomatically\nupdated.Five9makeseveryefforttotestandsupportthemost\nrecentversion.\nFirefox Mostrecentthreestableversions.\nSafari Versions12,13,and14arenotsupportedoncurrentversionsof\nMacOS.1\n1Versions10and11weresupportedonolderversionsofMacOS.\nWorkstation Requirements for Five9 Video\nEngagement\nHardware\nWindows Requirements\nComponent Minimum Version orValue Recommended Version orValue\nProcessor IntelCorei5-4440,CPU2.10GHZ IntelCorei7-4770,CPU3.40GHz\nMemory 8GB 16GB\nScreenResolution 1024x768 1024x768\n21 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'AgentandSupervisorApplications Web-BasedApplicationRequirements Browser Version seepreviewandproactivechat,email,andsurveyconsoleoffers. Insteadtheyseeamessagerecommendingthattheyupgradeto version11.Inthatcase,recommendthattheyenablelocalstorage: Tools>InternetOptions>Advanced>Security>EnableDOM storage. 1Five9doesnotrecommendusingFirefoxforWebRTCwhenmultipletabsareused. Apple Mac Platforms MacOSXis64-bitonly. Browser Version GoogleChromeTM Mostrecentthreestableversions.GoogleChromeisautomatically updated.Five9makeseveryefforttotestandsupportthemost recentversion. Firefox Mostrecentthreestableversions. Safari Versions12,13,and14arenotsupportedoncurrentversionsof MacOS.1 1Versions10and11weresupportedonolderversionsofMacOS. Workstation Requirements for Five9 Video Engagement Hardware Windows Requirements Component Minimum Version orValue Recommended Version orValue Processor IntelCorei5-4440,CPU2.10GHZ IntelCorei7-4770,CPU3.40GHz Memory 8GB 16GB ScreenResolution 1024x768 1024x768 21 TechnicalRequirementsReferenceGuide'}
# ...
# {'page_number': 93, 'text': 'WorkforceOptimizationRequirements SupervisorWorkstationRequirements\nBrowser Version (32-bit)\nEdge Latestrelease.\nSafari Latestrelease.\nInternetExplorer Version9orhigher.\nSoftware Requirements\nComponent Requirement\nWindowsMediaPlayer Version9orhigher\nConfiguration Requirements\nComponent Requirement\nLocalFirewall ExceptionstolocalWindowsFirewallpoliciesmayberequired\ndependingonsite-specificpolicies.\nSeedeploymentinstructionsforfurtherdetail.\nLocalAnti-VirusorAnti- ExceptionstolocalAVormalwaredetectionapplicationsmay\nMalware berequireddependingonsite-specificpolicies.\nAddthefollowingexecutablesinanyanti-virusoranti-\nmalwareprogram:\n<InstallationDirectory>\\voacli.exe\nl\n<InstallationDirectory>\\voacld.exe\nl\n<InstallationDirectory>\\voacsc.exe\nl\n<InstallationDirectory>\\voacmt.exe\nl\n<InstallationDirectory>\\voacse.exe\nl\n<InstallationDirectory>\\voaclm.exe\nl\n<InstallationDirectory>\\RC\\voacvc.exe\nl\nFirewall Policies\nSource Destination Port Protocol Description\nSupervisorPC WFOCLOUD 443 TCP ApplicationAccess.\n93 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'WorkforceOptimizationRequirements SupervisorWorkstationRequirements Browser Version (32-bit) Edge Latestrelease. Safari Latestrelease. InternetExplorer Version9orhigher. Software Requirements Component Requirement WindowsMediaPlayer Version9orhigher Configuration Requirements Component Requirement LocalFirewall ExceptionstolocalWindowsFirewallpoliciesmayberequired dependingonsite-specificpolicies. Seedeploymentinstructionsforfurtherdetail. LocalAnti-VirusorAnti- ExceptionstolocalAVormalwaredetectionapplicationsmay Malware berequireddependingonsite-specificpolicies. Addthefollowingexecutablesinanyanti-virusoranti- malwareprogram: <InstallationDirectory>\\voacli.exe l <InstallationDirectory>\\voacld.exe l <InstallationDirectory>\\voacsc.exe l <InstallationDirectory>\\voacmt.exe l <InstallationDirectory>\\voacse.exe l <InstallationDirectory>\\voaclm.exe l <InstallationDirectory>\\RC\\voacvc.exe l Firewall Policies Source Destination Port Protocol Description SupervisorPC WFOCLOUD 443 TCP ApplicationAccess. 93 TechnicalRequirementsReferenceGuide'}
# {'page_number': 94, 'text': 'WorkforceOptimizationRequirements BandwidthConsiderations\nBandwidth Considerations\nInternetbandwidthisusedbyFive9WorkforceOptimization(WFO)bytwoprimary\nmechanisms.\nUserplaybackofmediainQualityMonitoring(QM)usesbandwidth,whetherbya\nsupervisororagent.Inthisscenario,mediaisstreamedfromtheWFOcloud\nenvironmenttotheuserworkstation.\nScreencaptureusesbandwidthwhenscreencachedataismovedfromtheagent\npremisetotheWFOcloudenvironment.\nUserMediaPlayback\nScreenCaptureCacheTransmission\nExampleScreenCaptureCalculation\nUser Media Playback\nPlaybackType PlaybackBandwidth Rate\nAudioOnly 100KBps\nAudio&ScreenCapture(1monitor) 300KBps\nAudio&ScreenCapture(2monitors) 600KBps\nAudio&ScreenCapture(3monitors) 900KBps\nScreen Capture Cache Transmission\nCaptureType AverageDataTransmission, AverageTransmission Rate\nPerMinuteRecorded\n1Monitor 1.5MB 1500KBps\n2Monitors 2.0MB 1500KBps\n3Monitors 3.0MB 1500KBps\nScreencaptureusageestimatesareprovidedforinitialsizingonly.Actualusagecanvary\ngreatlydependingonscreencontent,activity,monitorresolution,andother\nenvironmentalfactors.Five9recommendsthatforsite-specificbandwidthusage\nmetrics,runapilotgrouptestduringdeployment.\n94 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'WorkforceOptimizationRequirements BandwidthConsiderations Bandwidth Considerations InternetbandwidthisusedbyFive9WorkforceOptimization(WFO)bytwoprimary mechanisms. UserplaybackofmediainQualityMonitoring(QM)usesbandwidth,whetherbya supervisororagent.Inthisscenario,mediaisstreamedfromtheWFOcloud environmenttotheuserworkstation. Screencaptureusesbandwidthwhenscreencachedataismovedfromtheagent premisetotheWFOcloudenvironment. UserMediaPlayback ScreenCaptureCacheTransmission ExampleScreenCaptureCalculation User Media Playback PlaybackType PlaybackBandwidth Rate AudioOnly 100KBps Audio&ScreenCapture(1monitor) 300KBps Audio&ScreenCapture(2monitors) 600KBps Audio&ScreenCapture(3monitors) 900KBps Screen Capture Cache Transmission CaptureType AverageDataTransmission, AverageTransmission Rate PerMinuteRecorded 1Monitor 1.5MB 1500KBps 2Monitors 2.0MB 1500KBps 3Monitors 3.0MB 1500KBps Screencaptureusageestimatesareprovidedforinitialsizingonly.Actualusagecanvary greatlydependingonscreencontent,activity,monitorresolution,andother environmentalfactors.Five9recommendsthatforsite-specificbandwidthusage metrics,runapilotgrouptestduringdeployment. 94 TechnicalRequirementsReferenceGuide'}
# {'page_number': 95, 'text': 'WorkforceOptimizationRequirements BandwidthConsiderations\nExample Screen Capture Calculation\nThefollowingexpressioncanbeusedforscreencapturecalculation.\nNumber of Agents (x) Monitors for each computer(x) Minutes Recorded (x)\nData Transmission Size = Total Daily Upload\nExample\n50agents(x)2monitors(x)18,000minutesrecordedperday(x)2.0MBper\nminutecaptured=3.5GBuploadperday\n95 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'WorkforceOptimizationRequirements BandwidthConsiderations Example Screen Capture Calculation Thefollowingexpressioncanbeusedforscreencapturecalculation. Number of Agents (x) Monitors for each computer(x) Minutes Recorded (x) Data Transmission Size = Total Daily Upload Example 50agents(x)2monitors(x)18,000minutesrecordedperday(x)2.0MBper minutecaptured=3.5GBuploadperday 95 TechnicalRequirementsReferenceGuide'}
# {'page_number': 96, 'text': "References\nGlossary\nReferenceDocuments\nGlossary\nTerm/Acronym Definition\nACL Liststhatfilternetworktrafficbycontrollingwhetherroutedpackets\nareforwardedorblockedattherouter'sinterfaces.Yourrouter\nexamineseachpackettodeterminewhethertoforwardordropthe\npacket,basedonthecriteriayouspecifiedwithintheaccesslists.\nCodec Codecsareusedtoconvertananalogvoicesignaltodigitallyencoded\nversion.Codecsvaryinsoundqualityandbandwidthrequired.\nCTI ComputerTelephonyIntegration.\nDiffservQoS DifferentiatedServices(Diffserv)QoSframeworkenablesquality-of-\nserviceprovisioninginanetworkdomainbyapplyingrulesatthe\nedgestocreatetrafficaggregatesandbycouplingeachofthesewith\naspecificforwardingpathtreatmentinthedomainthroughuseofa\ncodepointintheIPheader.\nDigitalCertificate DigitalCertificatesprovideameansofprovingidentityinelectronic\ntransactions.Alsoknownasapublickeycertificate,thedigital\ncertificateisanelectronicdocumentthatusesdigitalsignatureto\nbindapublickeywithanidentity—informationsuchasthenameofa\npersonoranorganization,theiraddress,andsoforth.Thecertificate\ncanbeusedtoverifythatapublickeybelongstoanindividual.\nG.711 TwomainVoIPcompressionalgorithms:\nµ-lawalgorithmisusedinNorthAmerica&Japan.\nl\nA-lawalgorithmisusedintherestoftheworld.Thesamplerateis\nl\n64kbit/sbit.\nG.729 ITUstandardcodecwithtwomainversions:AandB.ForVoIP\nprocessing,thesampleraterangesfrom28to40kbit/sbit,depending\nonoverhead.\n96 TechnicalRequirements•ReferenceGuide", 'cleaned_text': "References Glossary ReferenceDocuments Glossary Term/Acronym Definition ACL Liststhatfilternetworktrafficbycontrollingwhetherroutedpackets areforwardedorblockedattherouter'sinterfaces.Yourrouter examineseachpackettodeterminewhethertoforwardordropthe packet,basedonthecriteriayouspecifiedwithintheaccesslists. Codec Codecsareusedtoconvertananalogvoicesignaltodigitallyencoded version.Codecsvaryinsoundqualityandbandwidthrequired. CTI ComputerTelephonyIntegration. DiffservQoS DifferentiatedServices(Diffserv)QoSframeworkenablesquality-of- serviceprovisioninginanetworkdomainbyapplyingrulesatthe edgestocreatetrafficaggregatesandbycouplingeachofthesewith aspecificforwardingpathtreatmentinthedomainthroughuseofa codepointintheIPheader. DigitalCertificate DigitalCertificatesprovideameansofprovingidentityinelectronic transactions.Alsoknownasapublickeycertificate,thedigital certificateisanelectronicdocumentthatusesdigitalsignatureto bindapublickeywithanidentityinformationsuchasthenameofa personoranorganization,theiraddress,andsoforth.Thecertificate canbeusedtoverifythatapublickeybelongstoanindividual. G.711 TwomainVoIPcompressionalgorithms: -lawalgorithmisusedinNorthAmerica&Japan. l A-lawalgorithmisusedintherestoftheworld.Thesamplerateis l 64kbit/sbit. G.729 ITUstandardcodecwithtwomainversions:AandB.ForVoIP processing,thesampleraterangesfrom28to40kbit/sbit,depending onoverhead. 96 TechnicalRequirementsReferenceGuide"}
# {'page_number': 97, 'text': 'References Glossary\nTerm/Acronym Definition\nMPLS MultiprotocolLabelSwitching(MPLS)isapureIParchitecturethat\ncombinesthestrengthsofLayer-3routingandLayer-2switching.\nMPLScarriernetworksarescalablevirtualprivatenetworks(VPNs)\nthatprovideend-to-endqualityofservice(QoS).\nNAT NetworkAddressTranslationtranslatesIPaddressesusedinone\nnetworktoadifferentIPaddressknowntoanothernetwork.\nPAT PortAddressTranslationworkswithNATtoconserveIPaddresses\nusedbypermittingmultipledevicesonalocalareanetwork(LAN)to\nbemappedtoasingleIPaddress.\nRTPprotocol Real-TimeTransportisusedwiththeRTPControlProtocol(RTCP).RTP\ncarriesthemediastreams,suchasaudioandvideowhereasRTCP\nmonitorstransmissionstatisticsandqualityofservice(QoS)andhelps\ntosynchronizemultiplestreams.WithWebRTC,STUNprotocol\nmessagesaresentthroughtheseports.\nSBC SessionBorderController(SBC)isadevicedeployedinVoiceover\nInternetProtocol(VoIP)networkstoexertcontroloverthesignaling\nandusuallythemediastreamsinvolvedinsettingup,conducting,and\ntearingdownSIPcalls.\nSIP SessionInitiationProtocolworksintheApplicationLayertocontrol\ncommunicationsforvideo,voice,IP,unicast,andmulticastsessions.\nSIPALG SIP-ALGisafirewallthatcanperformNATwithstandardSIP\nprotocols.\nSIPInspection TosupportSIPcallsthroughthesecurityappliance,signalingmessages\nforthemediaconnectionaddresses,mediaports,andembryonic\nconnectionsforthemediamustbeinspected,becausewhilethe\nsignalingissentoverawell-knowndestinationport(UDP/TCP5060),\nthemediastreamsaredynamicallyallocated.Also,SIPembedsIP\naddressesintheuser-dataportionoftheIPpacket.SIPinspection\nappliesNATfortheseembeddedIPaddresses.\nSIPTrunking SIPtrunksareVoIP-basedcarrierservicesbasedontheSession\nInitiationProtocol(SIP)bywhichInternettelephonyserviceproviders\n(ITSPs)delivertelephonyPSTNServices.\nSTUNprotocol SessionTraversalUtilitiesforNATisaNetworkAddressTranslator\n(NAT)traversaltoolforotherprotocols.STUNcanbeusedbyan\nendpointtodeterminetheIPaddressandportallocatedtoitbya\nNAT.\nTCP/UDPPorts TransportLayerprotocols,suchasTransmissionControlProtocol\n(TCP),theUserDatagramProtocol(UDP);specifyasourceand\n97 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'References Glossary Term/Acronym Definition MPLS MultiprotocolLabelSwitching(MPLS)isapureIParchitecturethat combinesthestrengthsofLayer-3routingandLayer-2switching. MPLScarriernetworksarescalablevirtualprivatenetworks(VPNs) thatprovideend-to-endqualityofservice(QoS). NAT NetworkAddressTranslationtranslatesIPaddressesusedinone networktoadifferentIPaddressknowntoanothernetwork. PAT PortAddressTranslationworkswithNATtoconserveIPaddresses usedbypermittingmultipledevicesonalocalareanetwork(LAN)to bemappedtoasingleIPaddress. RTPprotocol Real-TimeTransportisusedwiththeRTPControlProtocol(RTCP).RTP carriesthemediastreams,suchasaudioandvideowhereasRTCP monitorstransmissionstatisticsandqualityofservice(QoS)andhelps tosynchronizemultiplestreams.WithWebRTC,STUNprotocol messagesaresentthroughtheseports. SBC SessionBorderController(SBC)isadevicedeployedinVoiceover InternetProtocol(VoIP)networkstoexertcontroloverthesignaling andusuallythemediastreamsinvolvedinsettingup,conducting,and tearingdownSIPcalls. SIP SessionInitiationProtocolworksintheApplicationLayertocontrol communicationsforvideo,voice,IP,unicast,andmulticastsessions. SIPALG SIP-ALGisafirewallthatcanperformNATwithstandardSIP protocols. SIPInspection TosupportSIPcallsthroughthesecurityappliance,signalingmessages forthemediaconnectionaddresses,mediaports,andembryonic connectionsforthemediamustbeinspected,becausewhilethe signalingissentoverawell-knowndestinationport(UDP/TCP5060), themediastreamsaredynamicallyallocated.Also,SIPembedsIP addressesintheuser-dataportionoftheIPpacket.SIPinspection appliesNATfortheseembeddedIPaddresses. SIPTrunking SIPtrunksareVoIP-basedcarrierservicesbasedontheSession InitiationProtocol(SIP)bywhichInternettelephonyserviceproviders (ITSPs)delivertelephonyPSTNServices. STUNprotocol SessionTraversa ...
# {'page_number': 98, 'text': 'References ReferenceDocuments\nTerm/Acronym Definition\ndestinationportnumberintheirpacketheaders.Aportnumberisa\n16-bitunsignedinteger,rangingfrom0to65535.Aprocessassociates\nitsinputoroutputchannelsviaInternetsockets,atypeoffile\ndescriptors,withatransportprotocol,aportnumberandanIP\naddress.Thisprocessisknownasbinding,whichenablessendingand\nreceivingdataviathenetwork.\nTLS TransportLayerSecurityprotocolthatprovidesdatasecrecyand\nintegritybetweenapplications.\nVoIP VoiceoverInternetProtocol.Voicesignalsaretransmittedoverthe\nInternetratherthanoverthepublicswitchedtelephonenetwork\n(PSTN).\nVPN VirtualPrivateNetworkextendsaprivatenetworksothatthe\nresourcesthatbelongtothatnetworkareavailablebycontrolled\nremoteaccess.\nWebRTC WebReal-TimeCommunicationisanAPIdefinitiondraftedbythe\nWorldWideWebConsortium(W3C)tosupportbrowser-to-browser\napplicationsforvoice,videochat,andP2Pfilesharingwithouteither\ninternalorexternalplug-ins.\nWSS SecureWebSocketprotocol.Providessecure,full-duplex\ncommunicationchannelsoverasingleTCPconnection.Usedinweb\nbrowsersandwebservers.\nReference Documents\nDocumentName Link\nSessionInitiationProtocol http://en.wikipedia.org/wiki/Session_Initiation_\nProtocol\nRFC3261SIP:SessionInitiation http://www.ietf.org/rfc/rfc3261.txt\nProtocol\nVoIPReferenceGuide http://www.voip-info.org/wiki/view/SIP\nSIPReferenceandTraining http://www.thesipschool.com/\nWebRTC-Wikipedia http://en.wikipedia.org/wiki/WebRTC\n98 TechnicalRequirements•ReferenceGuide', 'cleaned_text': 'References ReferenceDocuments Term/Acronym Definition destinationportnumberintheirpacketheaders.Aportnumberisa 16-bitunsignedinteger,rangingfrom0to65535.Aprocessassociates itsinputoroutputchannelsviaInternetsockets,atypeoffile descriptors,withatransportprotocol,aportnumberandanIP address.Thisprocessisknownasbinding,whichenablessendingand receivingdataviathenetwork. TLS TransportLayerSecurityprotocolthatprovidesdatasecrecyand integritybetweenapplications. VoIP VoiceoverInternetProtocol.Voicesignalsaretransmittedoverthe Internetratherthanoverthepublicswitchedtelephonenetwork (PSTN). VPN VirtualPrivateNetworkextendsaprivatenetworksothatthe resourcesthatbelongtothatnetworkareavailablebycontrolled remoteaccess. WebRTC WebReal-TimeCommunicationisanAPIdefinitiondraftedbythe WorldWideWebConsortium(W3C)tosupportbrowser-to-browser applicationsforvoice,videochat,andP2Pfilesharingwithouteither internalorexternalplug-ins. WSS SecureWebSocketprotocol.Providessecure,full-duplex communicationchannelsoverasingleTCPconnection.Usedinweb browsersandwebservers. Reference Documents DocumentName Link SessionInitiationProtocol http://en.wikipedia.org/wiki/Session_Initiation_ Protocol RFC3261SIP:SessionInitiation http://www.ietf.org/rfc/rfc3261.txt Protocol VoIPReferenceGuide http://www.voip-info.org/wiki/view/SIP SIPReferenceandTraining http://www.thesipschool.com/ WebRTC-Wikipedia http://en.wikipedia.org/wiki/WebRTC 98 TechnicalRequirementsReferenceGuide'}

# %%
# 🧾 Optional: Extract Basic Metadata Heuristically

# Example: Extract first few lines as Title/Heading
def get_doc_title(text):
    lines = text.split('\n')
    if lines:
        return lines[0]
    return "Untitled Document"

document_title = get_doc_title(text_pages[0]["text"])
print("Document Title:", document_title)
# Out:
# Document Title: CloudContactCenter

# %% [markdown]
# 🚀 Phase 2 – Partitioner
#
# 🎯 Objective:
# Split your document into meaningful semantic blocks like:
#
# - Title
# - Section headers (e.g., 1. Introduction, 2. Overview of Systems)
# - Bullet points, paragraphs, tables, etc.
#
# Why Partition?
# Raw page-level text is too coarse. We need fine-grained segments to:
#
# - Assign meaning
# - Enrich in the next phase
# - Chunk effectively later
#
# 📦 Two Partitioning Approaches
#
# 🔹 Option A: Simple Heuristics (Best to Start With)
#
# Based on patterns like:
#
# - Line starts with number: ^\d+\. → Section heading
# - Bullet points: starts with •, -, or o
# - Paragraph: blocks separated by double newline
#
# 🔹 Option B: Use unstructured.partition (Optional, layout-aware)
#
# - Automatically splits documents into:
# - Title, Narrative Text, List Items, Tables, Headers
# - Handles multi-column or noisy layouts better

# %% [markdown]
# # Option A : First (Simple Heuristics)

# %%
# ✅ Step 1: Extract Sections by Numbered Headers

import re

def partition_by_headings(text):
    # Split by headers like: 1. Introduction, 2. Overview of Systems, etc.
    pattern = r'(?=\d+\.\s+[A-Z])'
    sections = re.split(pattern, text)
    structured_blocks = []

    for idx, section in enumerate(sections):
        section = section.strip()
        if section:
            lines = section.split('\n')
            title_line = lines[0].strip()
            body = '\n'.join(lines[1:]).strip() if len(lines) > 1 else ""
            structured_blocks.append({
                "section_id": idx + 1,
                "heading": title_line,
                "content": body
            })
    
    return structured_blocks

# %%
# Step 2: Apply to Your First Page (or Entire Doc)
all_sections = []
for page in text_pages:
    sections = partition_by_headings(page["cleaned_text"])
    all_sections.extend(sections)

print(f"Total Sections Found: {len(all_sections)}")
for sec in all_sections[:6]:  # Print first 3 sections
    print(f"\nSection: {sec['heading']}\nContent: {sec['content'][:300]}...")
# Out:
# Total Sections Found: 136
#
# Section: CloudContactCenter Software Technical Requirements Reference Guide August 2021 This guide contains deployment, configuration, and troubleshooting information to assist customers and partners with Five9 applications. Five9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe claimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange withoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright  2021Five9,Inc.
# Content: ...
#
# Section: About Five9 Five9istheleadingproviderofcloudcontactcentersoftware,bringingthepowerof thecloudtothousandsofcustomersandfacilitatingmorethanthreebillioncustomer interactionsannually.Since2001,Five9hasledthecloudrevolutionincontactcenters, deliveringsoftwaretohelporganizationsofeverysizetransitionfrompremise-based softwaretothecloud.Withitsextensiveexpertise,technology,andecosystemof partners,Five9deliverssecure,reliable,scalablecloudcontactcentersoftwaretohelp businessescreateexceptionalcustomerexperiences,increaseagentproductivityand delivertangibleresults.Formoreinformationvisitwww.five9.com. Trademarks Five9 Five9Logo Five9SoCoCareTM Five9ConnectTM 2 TechnicalRequirementsReferenceGuide
# Content: ...
#
# Section: Contents WhatsNew 8 Environment and Security 10 RMI Protocol 10 RTPProtocol 10 VoiceQuality Testing 11 Digital Certificates 11 DigiCertCertificates 12 SupportedTLSProtocols 12 TLSInboundCipherSuites 13 TLS1.2 InboundCipherSuites 13 TLS1.1 InboundCipherSuites 13 TLSOutboundCipherSuites 13 Setting theTLSProtocolsinYourBrowser 14 Chrome 14 Firefox 15 AppleSafari 15 InternetExplorer 15 Five9 SIP TrunkOptions 16 PrivateSIPTrunksProvidedby Five9 ITSPProviders 16 SIPTrunksProvidedby YourITSPProvider 17 PrivateSIPTrunksforFive9 Gateway toCustomerGateway 17 Agent and SupervisorApplications 18 Web-BasedApplicationRequirements 18 Workstations 18 Hardware 18 WindowsPlatforms 18 AppleMac Platforms 19 Chromebooks 19 Operating Systems 19 WebBrowsers 20 WindowsPlatforms 20 AppleMac Platforms 21 WorkstationRequirementsforFive9 VideoEngagement 21 Hardware 21 3 TechnicalRequirementsReferenceGuide
# Content: ...
#
# Section: WindowsRequirements 21 AppleMac Requirements 22 Operating Systems 22 WebBrowsers 22 WindowsPlatforms 22 AppleMac Platforms 23 MobileDevices 23 VideoCameras 23 Five9 AgentAssistRequirements 24 UnifiedCommunications(UC) AdaptersforSkypeforBusiness 25 Virtual DesktopInfrastructureRequirements 25 Hardware 25 Operating Systems 26 Virtual DesktopInfrastructure 26 Citrix Platforms 26 VMwarePlatforms 27 Java-BasedApplicationRequirements 27 Hardware 28 WindowsPlatforms 28 AppleMac Platforms 28 Java Runtime 29 Operating Systems 29 WindowsandMac (32- and64-Bit) 29 Five9 AgentorSupervisorWorkstationUserAccessControl 29 WebBrowsers 30 WindowsPlatforms(32-bitversiononly) 30 AppleMac Platforms 30 Five9 Supervisor 30 AppleiPad 30 WorkstationRequirementsforSpreadsheetDashboards 31 HeadsetforAgentsandSupervisors 31 ApplicationNotes 32 WebPageSecurity andVisual IVR Scripts 32 Dashboards 32 AgentDesktopPluswithDigital Engagement 33 IntegratedAdministrationConsole 33 Five9 Agent Integrations 34 RequirementsforWeb-BasedAdapters 34 WorkstationRequirements 35 Hardware 35 WindowsPlatforms 35 AppleMac Platforms 35 Operating Systems 35 4 TechnicalRequirementsReferenceGuide
# Content: ...
#
# Section: WebBrowsers 36 ApplicationRequirements 37 PlusAdapterforAgentDesktopToolkit 37 PlusAdapterforSalesforce 37 PlusAdapterforOracleServiceCloud 37 PlusAdapterforNetSuite 37 PlusAdapterforMicrosoftDynamics365 37 PlusAdapterforZendesk 38 PlusAdapterforServiceNow 38 RequirementsforJava-BasedAdapters 38 WorkstationRequirements 38 Hardware 38 Operating Systems 38 Java Requirements 39 WebBrowsers 39 ApplicationRequirements 40 Five9 AgentDesktopToolkit 40 Five9 OpenCTI AdapterforSalesforce 40 Five9 AdapterforNetSuite 40 Five9 AdapterforOracleServiceCloud 40 Five9 AdapterforVelocify 41 Five9 CloudAPI WebServices(CustomIntegration) 41 Verint SystemsRequirements 42 WorkstationRequirements 42 HardwareRequirements 42 Third-Party SoftwareRequiredforAgentStations 43 Third-Party SoftwareRequiredforBrowsing 45 JRESettingsRequirements 45 SupportedOperating Systems 47 SupportedWebBrowsers 47 InternetExplorer 47 GoogleChrome 53 BrowserRequirementsforVerintPlayer 56 Network Requirements(LAN andWAN) 57 Firewall Requirements 57 CalabrioApplication Requirements 58 DesktopRequirements 58 WindowsOperating Systems 58 .NET Framework 59 WebBrowsers 59 CaptureBandwidth 59 AnalyticsandPlug-inExtensions 59 5 TechnicalRequirementsReferenceGuide
# Content: ...
#
# Section: AntivirusReal-TimeScanning Exclusions 60 Firewall Requirements 60 StudioRequirements 61 Public InternetDomains 61 WebServiceIntegrationIPAddresses 61 SBC Public IPAddresses 63 Media ServerPublic IPAddresses 64 Network 66 Five9 Network Connectivity 66 Virtual PrivateNetwork (VPN) 66 VPN andQuality of Service(QOS) 66 VPN andPrivateIPAddresses 67 DirectConnectionOption 67 RequiredDirectConnectionCriteria 67 WebRTC 68 Five9 Network Requirements(LAN andWAN) 69 Five9 BandwidthRequirements 69 Five9 Network Recommendations 70 BandwidthRequirementsforFive9 VideoEngagementforAgents 71 OtherVoIPServicesandPhones, Ports, IPAddressRanges, andNetwork Traffic 72 Five9 InternetDomainsandIPAddresses 72 Five9 IPAddressRanges 73 Five9 IPAddressesforGlobal Voice 75 Five9 IPAddressesforEmail 75 Five9 Connectivity AssessmentTest 76 Five9 IPAddressesforCallback API Integration 76 Five9 InternetDomains 77 CounterPathSoftphoneRequirements 80 PerformanceDashboard 80 SIPFirewall Note 81 TCP/UDPPortRequirementsforSoftphoneCustomers 81 TCP/UDPPortRequirementsforGateway Customers 82 TCP/UDPPortRequirementsforPSTN Customers 83 TCPandUDPPortsforConnectivity AssessmentTest 84 TCPPortRequirementsforFTP/SFTP 84 Network RequirementsforFive9 VideoEngagement 85 PortRequirementsforEmail 85 SOAPAPIs 86 Third-Party Software 86 Five9 Quality of Service(QoS) Features 86 WorkstationQoSOption 86 Network QoSOption 87 6 TechnicalRequirementsReferenceGuide
# Content: ...

# %%
for section in sections:
    print(f"\n🔍 Checking Section: {section['heading']}")  # instead of 'title'
    print(f"Content Length: {len(section['content'])}")
    print(f"Content: {section['content'][:300]}")  # preview only
# Out:
# 🔍 Checking Section: References ReferenceDocuments Term/Acronym Definition destinationportnumberintheirpacketheaders.Aportnumberisa 16-bitunsignedinteger,rangingfrom0to65535.Aprocessassociates itsinputoroutputchannelsviaInternetsockets,atypeoffile descriptors,withatransportprotocol,aportnumberandanIP address.Thisprocessisknownasbinding,whichenablessendingand receivingdataviathenetwork. TLS TransportLayerSecurityprotocolthatprovidesdatasecrecyand integritybetweenapplications. VoIP VoiceoverInternetProtocol.Voicesignalsaretransmittedoverthe Internetratherthanoverthepublicswitchedtelephonenetwork (PSTN). VPN VirtualPrivateNetworkextendsaprivatenetworksothatthe resourcesthatbelongtothatnetworkareavailablebycontrolled remoteaccess. WebRTC WebReal-TimeCommunicationisanAPIdefinitiondraftedbythe WorldWideWebConsortium(W3C)tosupportbrowser-to-browser applicationsforvoice,videochat,andP2Pfilesharingwithouteither internalorexternalplug-ins. WSS SecureWebSocketprotocol.Providessecure,full-duplex communicationchannelsoverasingleTCPconnection.Usedinweb browsersandwebservers. Reference Documents DocumentName Link SessionInitiationProtocol http://en.wikipedia.org/wiki/Session_Initiation_ Protocol RFC3261SIP:SessionInitiation http://www.ietf.org/rfc/rfc3261.txt Protocol VoIPReferenceGuide http://www.voip-info.org/wiki/view/SIP SIPReferenceandTraining http://www.thesipschool.com/ WebRTC-Wikipedia http://en.wikipedia.org/wiki/WebRTC 98 TechnicalRequirementsReferenceGuide
# Content Length: 0
# Content:

# %% [markdown]
# 🚀 Phase 3: Enrichment — Contextual Intelligence Layer
#
# 🎯 Objective:
# Enhance each section with structured metadata such as:
#
# - Named Entities (organizations, products, tech terms, dates, etc.)
# - Keyword highlights
# - (Optional) Intent or section classification (e.g., "architecture", "integration", "security")
#
# 🧰 Tools We'll Use: spaCy (lightweight & offline)
#
# We’ll use a pre-trained spaCy NLP model for:
# - Tokenization
#
# - Part-of-speech tagging
#
# - Named Entity Recognition (NER)

# %%
#📦 Step 1: Install and Load spaCy

# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Using cached spacy-3.8.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.13-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.10-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (2.3.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from spacy) (25.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.7.14)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.1.0)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.3.0.post1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from jinja2->spacy) (3.0.2)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading spacy-3.8.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.9/33.9 MB 18.1 MB/s eta 0:00:0000:0100:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 10.1 MB/s eta 0:00:00
# Downloading langcodes-3.5.0-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 8.1 MB/s eta 0:00:00
# Downloading murmurhash-1.0.13-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 4.1 MB/s eta 0:00:00
# Downloading preshed-3.0.10-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (869 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.3/869.3 kB 23.9 MB/s eta 0:00:0000:01
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.3 MB/s eta 0:00:00:00:01
# Downloading thinc-8.3.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 21.8 MB/s eta 0:00:0000:0100:01
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 2.0 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 31.9 MB/s eta 0:00:0000:0100:01
# Downloading cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.5 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 36.7 MB/s eta 0:00:0000:01:00:01
# Downloading smart_open-7.3.0.post1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 2.7 MB/s eta 0:00:00
# Downloading marisa_trie-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 32.7 MB/s eta 0:00:00:00:01
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, smart-open, murmurhash, marisa-trie, cloudpathlib, catalogue, blis, srsly, preshed, language-data, langcodes, confection, weasel, thinc, spacy
# Successfully installed blis-1.3.0 catalogue-2.0.10 cloudpathlib-0.21.1 confection-0.1.5 cymem-2.0.11 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 murmurhash-1.0.13 preshed-3.0.10 smart-open-7.3.0.post1 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 wasabi-1.1.3 weasel-0.4.1
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 5.8 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
#🧠 Step 2: Enrich Sections with Named Entities

def enrich_with_entities(section):
    doc = nlp(section["content"])
    entities = [{"text": ent.text, "label": ent.label_} for ent in doc.ents]
    return {
        **section,
        "entities": entities
    }

enriched_sections = [enrich_with_entities(sec) for sec in all_sections]

# %%
#🧪 Step 3: Preview Enriched Output

for sec in enriched_sections[:3]:
    print(f"\n🧩 Section: {sec['heading']}")
    print(f"🔍 Entities: {[e['text'] + ' (' + e['label'] + ')' for e in sec['entities']]}")
    print(f"📄 Content Preview: {sec['content'][:200]}...\n")
# Out:
# 🧩 Section: CloudContactCenter Software Technical Requirements Reference Guide August 2021 This guide contains deployment, configuration, and troubleshooting information to assist customers and partners with Five9 applications. Five9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe claimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange withoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright  2021Five9,Inc.
# 🔍 Entities: []
# 📄 Content Preview: ...
#
#
# 🧩 Section: About Five9 Five9istheleadingproviderofcloudcontactcentersoftware,bringingthepowerof thecloudtothousandsofcustomersandfacilitatingmorethanthreebillioncustomer interactionsannually.Since2001,Five9hasledthecloudrevolutionincontactcenters, deliveringsoftwaretohelporganizationsofeverysizetransitionfrompremise-based softwaretothecloud.Withitsextensiveexpertise,technology,andecosystemof partners,Five9deliverssecure,reliable,scalablecloudcontactcentersoftwaretohelp businessescreateexceptionalcustomerexperiences,increaseagentproductivityand delivertangibleresults.Formoreinformationvisitwww.five9.com. Trademarks Five9 Five9Logo Five9SoCoCareTM Five9ConnectTM 2 TechnicalRequirementsReferenceGuide
# 🔍 Entities: []
# 📄 Content Preview: ...
#
#
# 🧩 Section: Contents WhatsNew 8 Environment and Security 10 RMI Protocol 10 RTPProtocol 10 VoiceQuality Testing 11 Digital Certificates 11 DigiCertCertificates 12 SupportedTLSProtocols 12 TLSInboundCipherSuites 13 TLS1.2 InboundCipherSuites 13 TLS1.1 InboundCipherSuites 13 TLSOutboundCipherSuites 13 Setting theTLSProtocolsinYourBrowser 14 Chrome 14 Firefox 15 AppleSafari 15 InternetExplorer 15 Five9 SIP TrunkOptions 16 PrivateSIPTrunksProvidedby Five9 ITSPProviders 16 SIPTrunksProvidedby YourITSPProvider 17 PrivateSIPTrunksforFive9 Gateway toCustomerGateway 17 Agent and SupervisorApplications 18 Web-BasedApplicationRequirements 18 Workstations 18 Hardware 18 WindowsPlatforms 18 AppleMac Platforms 19 Chromebooks 19 Operating Systems 19 WebBrowsers 20 WindowsPlatforms 20 AppleMac Platforms 21 WorkstationRequirementsforFive9 VideoEngagement 21 Hardware 21 3 TechnicalRequirementsReferenceGuide
# 🔍 Entities: []
# 📄 Content Preview: ...

# %% [markdown]
# # Option 2: Keyword Extraction (Easy + Useful)

# %%
#Install and use KeyBERT (it uses BERT embeddings under the hood):

# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.18.5 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from keybert) (2.3.1)
# Requirement already satisfied: rich>=10.4.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from keybert) (14.1.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from keybert) (1.7.1)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from keybert) (5.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from rich>=10.4.0->keybert) (2.19.2)
# Requirement already satisfied: scipy>=1.8.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from scikit-learn>=0.22.2->keybert) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from scikit-learn>=0.22.2->keybert) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from scikit-learn>=0.22.2->keybert) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (4.54.1)
# Requirement already satisfied: tqdm in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (2.7.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (0.34.3)
# Requirement already satisfied: Pillow in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from sentence-transformers>=0.3.8->keybert) (4.14.1)
# Requirement already satisfied: filelock in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (6.0.2)
# Requirement already satisfied: requests in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (1.1.5)
# Requirement already satisfied: mdurl~=0.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: setuptools in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.14.0)
# Requirement already satisfied: networkx in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.5)
# Requirement already satisfied: jinja2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.3.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.3.8->keybert) (0.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.3.8->keybert) (2025.7.14)
# Downloading keybert-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 299.9 kB/s eta 0:00:0000:0100:01
# Installing collected packages: keybert
# Successfully installed keybert-0.9.0

# %%
#🧠 Step 2: Extract Keywords per Section

from keybert import KeyBERT

kw_model = KeyBERT(model='all-MiniLM-L6-v2')  # Light and powerful

def enrich_with_keywords(section):
    keywords = kw_model.extract_keywords(
        section["content"],
        keyphrase_ngram_range=(1, 2),
        stop_words='english',
        top_n=5
    )
    return {
        **section,
        "keywords": [kw[0] for kw in keywords]
    }

enriched_sections = [enrich_with_keywords(sec) for sec in all_sections]

# %%
#🔍 Step 3: Preview Output

for sec in enriched_sections[:3]:
    print(f"\n🧩 Section: {sec['heading']}")
    print(f"🔑 Keywords: {sec['keywords']}")
    print(f"📄 Content Preview: {sec['content'][:200]}...")
# Out:
# 🧩 Section: CloudContactCenter Software Technical Requirements Reference Guide August 2021 This guide contains deployment, configuration, and troubleshooting information to assist customers and partners with Five9 applications. Five9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe claimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange withoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright  2021Five9,Inc.
# 🔑 Keywords: []
# 📄 Content Preview: ...
#
# 🧩 Section: About Five9 Five9istheleadingproviderofcloudcontactcentersoftware,bringingthepowerof thecloudtothousandsofcustomersandfacilitatingmorethanthreebillioncustomer interactionsannually.Since2001,Five9hasledthecloudrevolutionincontactcenters, deliveringsoftwaretohelporganizationsofeverysizetransitionfrompremise-based softwaretothecloud.Withitsextensiveexpertise,technology,andecosystemof partners,Five9deliverssecure,reliable,scalablecloudcontactcentersoftwaretohelp businessescreateexceptionalcustomerexperiences,increaseagentproductivityand delivertangibleresults.Formoreinformationvisitwww.five9.com. Trademarks Five9 Five9Logo Five9SoCoCareTM Five9ConnectTM 2 TechnicalRequirementsReferenceGuide
# 🔑 Keywords: []
# 📄 Content Preview: ...
#
# 🧩 Section: Contents WhatsNew 8 Environment and Security 10 RMI Protocol 10 RTPProtocol 10 VoiceQuality Testing 11 Digital Certificates 11 DigiCertCertificates 12 SupportedTLSProtocols 12 TLSInboundCipherSuites 13 TLS1.2 InboundCipherSuites 13 TLS1.1 InboundCipherSuites 13 TLSOutboundCipherSuites 13 Setting theTLSProtocolsinYourBrowser 14 Chrome 14 Firefox 15 AppleSafari 15 InternetExplorer 15 Five9 SIP TrunkOptions 16 PrivateSIPTrunksProvidedby Five9 ITSPProviders 16 SIPTrunksProvidedby YourITSPProvider 17 PrivateSIPTrunksforFive9 Gateway toCustomerGateway 17 Agent and SupervisorApplications 18 Web-BasedApplicationRequirements 18 Workstations 18 Hardware 18 WindowsPlatforms 18 AppleMac Platforms 19 Chromebooks 19 Operating Systems 19 WebBrowsers 20 WindowsPlatforms 20 AppleMac Platforms 21 WorkstationRequirementsforFive9 VideoEngagement 21 Hardware 21 3 TechnicalRequirementsReferenceGuide
# 🔑 Keywords: []
# 📄 Content Preview: ...

# %% [markdown]
# ❓ Why Is KeyBERT Returning Empty Results?
#
# | Root Cause                               | What’s Happening                                                                                             |
# | ---------------------------------------- | ------------------------------------------------------------------------------------------------------------ |
# | 🔹 Section content is too short          | If there's not enough substance (e.g., just a heading or list), BERT can’t extract contextually rich phrases |
# | 🔹 Punctuation/formatting issues         | If sections are just a flat stream of bullet points or merged lines, models struggle                         |
# | 🔹 `keyphrase_ngram_range` is too narrow | We may miss 3-word technical terms like `"Agent Assist Engine"` or `"call flow integration"`                 |
# | 🔹 Token filtering too aggressive        | Stopword removal + short token length + flat formatting = no keywords                                        |
#
#
#
# 🛠 Let's Fix It Step-by-Step

# %%
#✅ Step 1: Try With Larger N-Gram Range
# Allow bigger phrases (e.g., 1 to 3 words):

def enrich_with_keywords(section):
    keywords = kw_model.extract_keywords(
        section["content"],
        keyphrase_ngram_range=(1, 3),  # increased range
        stop_words='english',
        top_n=5
    )
    return {
        **section,
        "keywords": [kw[0] for kw in keywords]
    }

# %%
#✅ Step 2: Sanity Check One Section Directly
#Pick a section that has some text, not just headings:

sample_section = all_sections[1]  # e.g., "1. Introduction"
print(sample_section["content"])

# %%
kw_model.extract_keywords(sample_section["content"], 
                          keyphrase_ngram_range=(1, 3), 
                          stop_words='english',
                          top_n=10)
# Out:
# []

# %%
#✅ Step 3: Add a Fallback for Very Short Sections
# Skip keyword extraction if content is < 50 characters:

def enrich_with_keywords(section):
    content = section["content"]
    if len(content) < 50:
        return {**section, "keywords": []}
    
    keywords = kw_model.extract_keywords(
        content,
        keyphrase_ngram_range=(1, 3),
        stop_words='english',
        top_n=5
    )
    return {
        **section,
        "keywords": [kw[0] for kw in keywords]
    }

# %%
# 🔎 Test the Output Again

for sec in enriched_sections[:3]:
    print(f"\n🧩 Section: {sec['heading']}")
    print(f"🔑 Keywords: {sec['keywords']}")
# Out:
# 🧩 Section: CloudContactCenter Software Technical Requirements Reference Guide August 2021 This guide contains deployment, configuration, and troubleshooting information to assist customers and partners with Five9 applications. Five9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe claimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange withoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright  2021Five9,Inc.
# 🔑 Keywords: []
#
# 🧩 Section: About Five9 Five9istheleadingproviderofcloudcontactcentersoftware,bringingthepowerof thecloudtothousandsofcustomersandfacilitatingmorethanthreebillioncustomer interactionsannually.Since2001,Five9hasledthecloudrevolutionincontactcenters, deliveringsoftwaretohelporganizationsofeverysizetransitionfrompremise-based softwaretothecloud.Withitsextensiveexpertise,technology,andecosystemof partners,Five9deliverssecure,reliable,scalablecloudcontactcentersoftwaretohelp businessescreateexceptionalcustomerexperiences,increaseagentproductivityand delivertangibleresults.Formoreinformationvisitwww.five9.com. Trademarks Five9 Five9Logo Five9SoCoCareTM Five9ConnectTM 2 TechnicalRequirementsReferenceGuide
# 🔑 Keywords: []
#
# 🧩 Section: Contents WhatsNew 8 Environment and Security 10 RMI Protocol 10 RTPProtocol 10 VoiceQuality Testing 11 Digital Certificates 11 DigiCertCertificates 12 SupportedTLSProtocols 12 TLSInboundCipherSuites 13 TLS1.2 InboundCipherSuites 13 TLS1.1 InboundCipherSuites 13 TLSOutboundCipherSuites 13 Setting theTLSProtocolsinYourBrowser 14 Chrome 14 Firefox 15 AppleSafari 15 InternetExplorer 15 Five9 SIP TrunkOptions 16 PrivateSIPTrunksProvidedby Five9 ITSPProviders 16 SIPTrunksProvidedby YourITSPProvider 17 PrivateSIPTrunksforFive9 Gateway toCustomerGateway 17 Agent and SupervisorApplications 18 Web-BasedApplicationRequirements 18 Workstations 18 Hardware 18 WindowsPlatforms 18 AppleMac Platforms 19 Chromebooks 19 Operating Systems 19 WebBrowsers 20 WindowsPlatforms 20 AppleMac Platforms 21 WorkstationRequirementsforFive9 VideoEngagement 21 Hardware 21 3 TechnicalRequirementsReferenceGuide
# 🔑 Keywords: []

# %%
for section in sections:
    print(f"\n🔍 Checking Section: {section['title']}")
    print(f"Content Length: {len(section['content'])}")
    print(f"Content: {section['content'][:300]}")  # Just first 300 chars
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 2
#       1 for section in sections:
# ----> 2     print(f"\n🔍 Checking Section: {section['title']}")
#       3     print(f"Content Length: {len(section['content'])}")
#       4     print(f"Content: {section['content'][:300]}")  # Just first 300 chars
#
# KeyError: 'title'

# %% [markdown]
# #  Use RAKE for Keyword Extraction

# %%
#🔧 Step 1: Install rake-nltk

# !pip install rake-nltk
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: rake-nltk in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from rake-nltk) (3.9.1)
# Requirement already satisfied: click in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.2.1)
# Requirement already satisfied: joblib in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/koyas/genai-lab-sandbox/venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.67.1)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/koyas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from rake_nltk import Rake

rake = Rake()  # Now it will work smoothly

def enrich_with_rake_keywords(section):
    content = section["content"]
    if len(content.strip()) < 30:
        return {**section, "keywords": []}
    
    rake.extract_keywords_from_text(content)
    keywords = rake.get_ranked_phrases()[:5]
    
    return {
        **section,
        "keywords": keywords
    }

enriched_sections = [enrich_with_rake_keywords(sec) for sec in all_sections]

# %%
for sec in enriched_sections[:3]:
    print(f"\n🧩 Section: {sec['heading']}")
    print(f"🔑 Keywords: {sec['keywords']}")
# Out:
# 🧩 Section: CloudContactCenter Software Technical Requirements Reference Guide August 2021 This guide contains deployment, configuration, and troubleshooting information to assist customers and partners with Five9 applications. Five9andtheFive9logoareregisteredtrademarksofFive9anditssubsidiariesintheUnitedStatesandothercountries.Othermarksandbrandsmaybe claimedasthepropertyofothers.Theproductplans,specifications,anddescriptionshereinareprovidedforinformationonlyandsubjecttochange withoutnotice,andareprovidedwithoutwarrantyofanykind,expressorimplied.Copyright  2021Five9,Inc.
# 🔑 Keywords: []
#
# 🧩 Section: About Five9 Five9istheleadingproviderofcloudcontactcentersoftware,bringingthepowerof thecloudtothousandsofcustomersandfacilitatingmorethanthreebillioncustomer interactionsannually.Since2001,Five9hasledthecloudrevolutionincontactcenters, deliveringsoftwaretohelporganizationsofeverysizetransitionfrompremise-based softwaretothecloud.Withitsextensiveexpertise,technology,andecosystemof partners,Five9deliverssecure,reliable,scalablecloudcontactcentersoftwaretohelp businessescreateexceptionalcustomerexperiences,increaseagentproductivityand delivertangibleresults.Formoreinformationvisitwww.five9.com. Trademarks Five9 Five9Logo Five9SoCoCareTM Five9ConnectTM 2 TechnicalRequirementsReferenceGuide
# 🔑 Keywords: []
#
# 🧩 Section: Contents WhatsNew 8 Environment and Security 10 RMI Protocol 10 RTPProtocol 10 VoiceQuality Testing 11 Digital Certificates 11 DigiCertCertificates 12 SupportedTLSProtocols 12 TLSInboundCipherSuites 13 TLS1.2 InboundCipherSuites 13 TLS1.1 InboundCipherSuites 13 TLSOutboundCipherSuites 13 Setting theTLSProtocolsinYourBrowser 14 Chrome 14 Firefox 15 AppleSafari 15 InternetExplorer 15 Five9 SIP TrunkOptions 16 PrivateSIPTrunksProvidedby Five9 ITSPProviders 16 SIPTrunksProvidedby YourITSPProvider 17 PrivateSIPTrunksforFive9 Gateway toCustomerGateway 17 Agent and SupervisorApplications 18 Web-BasedApplicationRequirements 18 Workstations 18 Hardware 18 WindowsPlatforms 18 AppleMac Platforms 19 Chromebooks 19 Operating Systems 19 WebBrowsers 20 WindowsPlatforms 20 AppleMac Platforms 21 WorkstationRequirementsforFive9 VideoEngagement 21 Hardware 21 3 TechnicalRequirementsReferenceGuide
# 🔑 Keywords: []

# %%
import nltk
nltk.download('punkt_tab')

sample_text = """
The Agent Assist Application integrates directly with PBX systems like Asterisk and Avaya.
It leverages CRM APIs to deliver real-time customer insights. This seamless integration helps agents reduce call time and improve customer satisfaction.
"""

print("RAKE:")
rake.extract_keywords_from_text(sample_text)
print(rake.get_ranked_phrases()[:5])

print("\nKeyBERT:")
kw_model.extract_keywords(sample_text, keyphrase_ngram_range=(1, 3), stop_words='english', top_n=5)
# Out:
# [nltk_data] Downloading package punkt_tab to /home/koyas/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# RAKE:
# ['seamless integration helps agents reduce call time', 'agent assist application integrates directly', 'pbx systems like asterisk', 'time customer insights', 'leverages crm apis']
#
# KeyBERT:
# [('agent assist application', 0.6803),
#  ('assist application integrates', 0.5592),
#  ('agent assist', 0.5513),
#  ('integration helps agents', 0.5197),
#  ('assist application', 0.5173)]

# %%
for section in sections:
    print(f"\n🔍 Checking Section: {section['title']}")
    print(f"Content Length: {len(section['content'])}")
    print(f"Content: {section['content'][:300]}")  # Just first 300 chars
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 2
#       1 for section in sections:
# ----> 2     print(f"\n🔍 Checking Section: {section['title']}")
#       3     print(f"Content Length: {len(section['content'])}")
#       4     print(f"Content: {section['content'][:300]}")  # Just first 300 chars
#
# KeyError: 'title'
